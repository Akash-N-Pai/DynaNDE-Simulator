# %%
import os
import re
import glob

# Base directory
base_dir = 'Encoder-BS32-SL512'

# Find all files matching the pattern
pattern = os.path.join(base_dir, 'flame-moe-*_layer*_*.txt')
files = glob.glob(pattern)

print("="*80)
print("Renaming layer files")
print("="*80)
print()

if not files:
    print("No files found matching the pattern")
else:
    print(f"Found {len(files)} file(s) to rename:\n")
    
    for file_path in files:
        # Extract layer number from filename
        filename = os.path.basename(file_path)
        match = re.search(r'layer(\d+)', filename)
        
        if match:
            layer_num = match.group(1)
            new_filename = f"layer{layer_num}.txt"
            new_path = os.path.join(base_dir, new_filename)
            
            print(f"  {filename}")
            print(f"    -> {new_filename}")
            
            # Rename the file
            try:
                os.rename(file_path, new_path)
                print(f"    ✓ Renamed successfully")
            except Exception as e:
                print(f"    ✗ ERROR: {e}")
            print()
        else:
            print(f"  Could not extract layer number from: {filename}")
            print()

print("="*80)
print("✓ Renaming complete!")
print("="*80)
# Out:
# ================================================================================
# Renaming layer files
# ================================================================================
#
# No files found matching the pattern
# ================================================================================
# ✓ Renaming complete!
# ================================================================================

# %%
import pandas as pd
import os
import re

# Base directory
base_dir = 'Decoder-BS32-deep'

# Numbered folders to process
numbered_folders = ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th']

# Store results for each experiment and numbered folder
all_experiment_results = []
numbered_folder_totals = []
grand_total = 0

print("="*80)
print("NPU-ONLY Mode Analysis - Decoder-BS64")
print("="*80)
print()

# Process each numbered folder
for folder_name in numbered_folders:
    npu_folder = os.path.join(base_dir, folder_name, 'npu')
    
    if not os.path.exists(npu_folder):
        print(f"⚠ {folder_name}/npu/ does not exist, skipping...")
        continue
    
    print(f"\n{folder_name}/:")
    print("-"*80)
    
    folder_total_cycles = 0
    experiment_count = 0
    
    # Process experiment folders 2-12
    for exp_num in range(2, 13):
        txt_file = os.path.join(npu_folder, str(exp_num), 'SA_stage_E.txt')
        
        if not os.path.exists(txt_file):
            continue
        
        # Read the text file
        with open(txt_file, 'r') as f:
            content = f.read()
        
        # Parse the table - extract data
        lines = content.split('\n')
        param_load_sum = 0
        expert_63_total_compute = 0
        
        for line in lines:
            # Skip empty lines and header lines
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'NPU Expert' in line or 'Decoder' in line:
                continue
            
            # Split by whitespace
            parts = line.split()
            
            if len(parts) >= 6:  # Should have: Expert Number, param_load, fc1, gelu, fc2, total compute
                try:
                    expert_num = int(parts[0])
                    param_load = int(parts[1])
                    total_compute = int(parts[5])
                    
                    # Sum all param_load values
                    param_load_sum += param_load
                    
                    # Store expert 63's total compute
                    if expert_num == 63:
                        expert_63_total_compute = total_compute
                except (ValueError, IndexError):
                    continue
        
        # Calculate experiment total
        exp_total = param_load_sum + expert_63_total_compute
        folder_total_cycles += exp_total
        experiment_count += 1
        
        # Store experiment result
        all_experiment_results.append({
            'Numbered Folder': folder_name,
            'Experiment': exp_num,
            'Sum of param_load': param_load_sum,
            'Expert 63 total compute': expert_63_total_compute,
            'Experiment Total': exp_total
        })
        
        print(f"  Exp {exp_num}: {exp_total:,} cycles")
    
    # Store numbered folder total
    if experiment_count > 0:
        numbered_folder_totals.append({
            'Numbered Folder': folder_name,
            'Experiments Processed': experiment_count,
            'Folder Total': folder_total_cycles
        })
        grand_total += folder_total_cycles
        
        print(f"  {'='*76}")
        print(f"  {folder_name} Total ({experiment_count} experiments): {folder_total_cycles:,} cycles")

# Create summary DataFrames
experiments_df = pd.DataFrame(all_experiment_results)
folders_df = pd.DataFrame(numbered_folder_totals)

print("\n" + "="*80)
print("Numbered Folder Totals")
print("="*80)
print(folders_df.to_string(index=False))

print("\n" + "="*80)
print(f"GRAND TOTAL (All NPU experiments): {grand_total:,} cycles")
print("="*80)

# Display folders DataFrame
folders_df
# Out:
# ================================================================================
# NPU-ONLY Mode Analysis - Decoder-BS64
# ================================================================================
#
#
# 1st/:
# --------------------------------------------------------------------------------
#   Exp 2: 86,265,524 cycles
#   Exp 3: 84,850,871 cycles
#   Exp 4: 84,851,796 cycles
#   Exp 5: 87,679,156 cycles
#   Exp 6: 83,436,288 cycles
#   Exp 7: 82,021,888 cycles
#   Exp 8: 79,193,897 cycles
#   Exp 9: 82,022,190 cycles
#   Exp 10: 86,265,524 cycles
#   Exp 11: 84,850,871 cycles
#   Exp 12: 84,851,796 cycles
#   ============================================================================
#   1st Total (11 experiments): 926,289,801 cycles
#
# 2nd/:
# --------------------------------------------------------------------------------
#   Exp 2: 86,265,269 cycles
#   Exp 3: 80,608,046 cycles
#   Exp 4: 80,608,553 cycles
#   Exp 5: 80,608,294 cycles
#   Exp 6: 79,194,549 cycles
#   Exp 7: 82,022,696 cycles
#   Exp 8: 77,780,012 cycles
#   Exp 9: 79,194,414 cycles
#   Exp 10: 86,265,269 cycles
#   Exp 11: 80,608,046 cycles
#   Exp 12: 80,608,553 cycles
#   ============================================================================
#   2nd Total (11 experiments): 893,763,701 cycles
#
# 3rd/:
# --------------------------------------------------------------------------------
#   Exp 2: 86,265,131 cycles
#   Exp 3: 83,436,840 cycles
#   Exp 4: 80,608,038 cycles
#   Exp 5: 84,850,985 cycles
#   Exp 6: 76,365,863 cycles
#   Exp 7: 77,780,006 cycles
#   Exp 8: 80,608,558 cycles
#   Exp 9: 79,194,548 cycles
#   Exp 10: 86,265,131 cycles
#   Exp 11: 83,436,840 cycles
#   Exp 12: 80,608,038 cycles
#   ============================================================================
#   3rd Total (11 experiments): 899,419,978 cycles
#
# 4th/:
# --------------------------------------------------------------------------------
#   Exp 2: 86,265,126 cycles
#   Exp 3: 90,507,557 cycles
#   Exp 4: 86,265,135 cycles
#   Exp 5: 86,265,268 cycles
#   Exp 6: 87,679,013 cycles
#   Exp 7: 86,264,320 cycles
#   Exp 8: 84,851,381 cycles
#   Exp 9: 87,679,275 cycles
#   Exp 10: 86,265,126 cycles
#   Exp 11: 90,507,557 cycles
#   Exp 12: 86,265,135 cycles
#   ============================================================================
#   4th Total (11 experiments): 958,814,893 cycles
#
# 5th/:
# --------------------------------------------------------------------------------
#   Exp 2: 83,436,587 cycles
#   Exp 3: 86,265,134 cycles
#   Exp 4: 83,436,838 cycles
#   Exp 5: 84,850,983 cycles
#   Exp 6: 86,265,268 cycles
#   Exp 7: 86,265,128 cycles
#   Exp 8: 83,436,590 cycles
#   Exp 9: 83,437,237 cycles
#   Exp 10: 83,436,587 cycles
#   Exp 11: 86,265,134 cycles
#   Exp 12: 83,436,838 cycles
#   ============================================================================
#   5th Total (11 experiments): 930,532,324 cycles
#
# 6th/:
# --------------------------------------------------------------------------------
#   Exp 2: 86,265,128 cycles
#   Exp 3: 82,022,837 cycles
#   Exp 4: 84,850,987 cycles
#   Exp 5: 84,850,989 cycles
#   Exp 6: 86,265,129 cycles
#   Exp 7: 83,436,288 cycles
#   Exp 8: 77,780,270 cycles
#   Exp 9: 84,850,729 cycles
#   Exp 10: 86,265,128 cycles
#   Exp 11: 82,022,837 cycles
#   Exp 12: 84,850,987 cycles
#   ============================================================================
#   6th Total (11 experiments): 923,461,309 cycles
#
# 7th/:
# --------------------------------------------------------------------------------
#   Exp 2: 83,436,841 cycles
#   Exp 3: 87,679,668 cycles
#   Exp 4: 86,264,870 cycles
#   Exp 5: 87,679,412 cycles
#   Exp 6: 82,022,695 cycles
#   Exp 7: 86,265,128 cycles
#   Exp 8: 84,850,983 cycles
#   Exp 9: 84,850,990 cycles
#   Exp 10: 83,436,841 cycles
#   Exp 11: 87,679,668 cycles
#   Exp 12: 86,264,870 cycles
#   ============================================================================
#   7th Total (11 experiments): 940,431,966 cycles
#
# 8th/:
# --------------------------------------------------------------------------------
#   Exp 2: 87,679,272 cycles
#   Exp 3: 87,679,019 cycles
#   Exp 4: 83,436,582 cycles
#   Exp 5: 86,265,131 cycles
#   Exp 6: 89,093,415 cycles
#   Exp 7: 87,678,720 cycles
#   Exp 8: 83,436,839 cycles
#   Exp 9: 86,265,131 cycles
#   Exp 10: 87,679,272 cycles
#   Exp 11: 87,679,019 cycles
#   Exp 12: 83,436,582 cycles
#   ============================================================================
#   8th Total (11 experiments): 950,328,982 cycles
#
# 9th/:
# --------------------------------------------------------------------------------
#   Exp 2: 84,850,982 cycles
#   Exp 3: 90,507,558 cycles
#   Exp 4: 89,093,813 cycles
#   Exp 5: 87,679,022 cycles
#   Exp 6: 89,093,417 cycles
#   Exp 7: 86,264,576 cycles
#   Exp 8: 83,437,236 cycles
#   Exp 9: 89,093,419 cycles
#   Exp 10: 84,850,982 cycles
#   Exp 11: 90,507,558 cycles
#   Exp 12: 89,093,813 cycles
#   ============================================================================
#   9th Total (11 experiments): 964,472,376 cycles
#
# 10th/:
# --------------------------------------------------------------------------------
#   Exp 2: 82,022,438 cycles
#   Exp 3: 80,608,038 cycles
#   Exp 4: 86,265,126 cycles
#   Exp 5: 83,436,846 cycles
#   Exp 6: 86,265,129 cycles
#   Exp 7: 82,022,443 cycles
#   Exp 8: 80,608,549 cycles
#   Exp 9: 84,850,990 cycles
#   Exp 10: 82,022,438 cycles
#   Exp 11: 80,608,038 cycles
#   Exp 12: 86,265,126 cycles
#   ============================================================================
#   10th Total (11 experiments): 914,975,161 cycles
#
# ================================================================================
# Numbered Folder Totals
# ================================================================================
# Numbered Folder  Experiments Processed  Folder Total
#             1st                     11     926289801
#             2nd                     11     893763701
#             3rd                     11     899419978
#             4th                     11     958814893
#             5th                     11     930532324
#             6th                     11     923461309
#             7th                     11     940431966
#             8th                     11     950328982
#             9th                     11     964472376
#            10th                     11     914975161
#
# ================================================================================
# GRAND TOTAL (All NPU experiments): 9,302,490,491 cycles
# ================================================================================
#   Numbered Folder  Experiments Processed  Folder Total
# 0             1st                     11     926289801
# 1             2nd                     11     893763701
# 2             3rd                     11     899419978
# 3             4th                     11     958814893
# 4             5th                     11     930532324
# 5             6th                     11     923461309
# 6             7th                     11     940431966
# 7             8th                     11     950328982
# 8             9th                     11     964472376
# 9            10th                     11     914975161

# %%
import pandas as pd
import os
import re

# Base directory
base_dir = 'Decoder-BS32-deep'

# Numbered folders to process
numbered_folders = ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th']

# Store results for each experiment and numbered folder
all_experiment_results = []
numbered_folder_totals = []
grand_total = 0

print("="*80)
print("PIM-ONLY Mode Analysis - Decoder-BS64")
print("="*80)
print()

# Process each numbered folder
for folder_name in numbered_folders:
    pim_folder = os.path.join(base_dir, folder_name, 'pim')
    
    if not os.path.exists(pim_folder):
        print(f"⚠ {folder_name}/pim/ does not exist, skipping...")
        continue
    
    print(f"\n{folder_name}/:")
    print("-"*80)
    
    folder_total_cycles = 0
    experiment_count = 0
    
    # Process experiment folders 2-12
    for exp_num in range(2, 13):
        txt_file = os.path.join(pim_folder, str(exp_num), 'SA_stage_E.txt')
        
        if not os.path.exists(txt_file):
            continue
        
        # Read the text file
        with open(txt_file, 'r') as f:
            content = f.read()
        
        # Parse activation movements
        activation_1 = 0
        activation_2 = 0
        
        # Extract activation movements from the file
        for line in content.split('\n'):
            if 'activation_movement_1' in line and 'cycles' in line:
                # Extract number before 'cycles' (handles both int and float)
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_1 = int(float(match.group(1)))
            elif 'activation_movement_2' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_2 = int(float(match.group(1)))
        
        # Parse the expert table
        lines = content.split('\n')
        total_compute_sum = 0
        
        for line in lines:
            # Skip empty lines and header lines
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'Note:' in line or 'Activation' in line or '-' in line[:3] or 'PIM Expert' in line or 'Decoder' in line or 'BS' in line:
                continue
            
            # Split by whitespace
            parts = line.split()
            
            if len(parts) >= 5:  # Should have: Expert Number, fc1, gelu, fc2, total compute
                try:
                    expert_num = int(parts[0])
                    total_compute = int(parts[4])  # Last column is total compute
                    
                    # Sum all total compute values
                    total_compute_sum += total_compute
                except (ValueError, IndexError):
                    continue
        
        # Calculate experiment total
        exp_total = total_compute_sum + activation_1 + activation_2
        folder_total_cycles += exp_total
        experiment_count += 1
        
        # Store experiment result
        all_experiment_results.append({
            'Numbered Folder': folder_name,
            'Experiment': exp_num,
            'Sum of total compute': total_compute_sum,
            'Activation 1': activation_1,
            'Activation 2': activation_2,
            'Experiment Total': exp_total
        })
        
        print(f"  Exp {exp_num}: {exp_total:,} cycles (compute: {total_compute_sum:,} + act: {activation_1 + activation_2:,})")
    
    # Store numbered folder total
    if experiment_count > 0:
        numbered_folder_totals.append({
            'Numbered Folder': folder_name,
            'Experiments Processed': experiment_count,
            'Folder Total': folder_total_cycles
        })
        grand_total += folder_total_cycles
        
        print(f"  {'='*76}")
        print(f"  {folder_name} Total ({experiment_count} experiments): {folder_total_cycles:,} cycles")

# Create summary DataFrames
experiments_df = pd.DataFrame(all_experiment_results)
folders_df = pd.DataFrame(numbered_folder_totals)

print("\n" + "="*80)
print("Numbered Folder Totals")
print("="*80)
print(folders_df.to_string(index=False))

print("\n" + "="*80)
print(f"GRAND TOTAL (All PIM experiments): {grand_total:,} cycles")
print("="*80)

# Display folders DataFrame
folders_df
# Out:
# ================================================================================
# PIM-ONLY Mode Analysis - Decoder-BS64
# ================================================================================
#
#
# 1st/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,670,373 cycles (compute: 1,661,405 + act: 8,968)
#   Exp 3: 1,597,617 cycles (compute: 1,588,649 + act: 8,968)
#   Exp 4: 1,664,896 cycles (compute: 1,655,928 + act: 8,968)
#   Exp 5: 1,783,903 cycles (compute: 1,774,935 + act: 8,968)
#   Exp 6: 1,665,740 cycles (compute: 1,656,772 + act: 8,968)
#   Exp 7: 1,712,284 cycles (compute: 1,703,316 + act: 8,968)
#   Exp 8: 1,592,879 cycles (compute: 1,583,911 + act: 8,968)
#   Exp 9: 1,688,320 cycles (compute: 1,679,352 + act: 8,968)
#   Exp 10: 1,670,373 cycles (compute: 1,661,405 + act: 8,968)
#   Exp 11: 1,597,617 cycles (compute: 1,588,649 + act: 8,968)
#   Exp 12: 1,664,896 cycles (compute: 1,655,928 + act: 8,968)
#   ============================================================================
#   1st Total (11 experiments): 18,308,898 cycles
#
# 2nd/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,667,450 cycles (compute: 1,658,482 + act: 8,968)
#   Exp 3: 1,662,186 cycles (compute: 1,653,218 + act: 8,968)
#   Exp 4: 1,708,736 cycles (compute: 1,699,768 + act: 8,968)
#   Exp 5: 1,661,036 cycles (compute: 1,652,068 + act: 8,968)
#   Exp 6: 1,775,984 cycles (compute: 1,767,016 + act: 8,968)
#   Exp 7: 1,666,991 cycles (compute: 1,658,023 + act: 8,968)
#   Exp 8: 1,641,295 cycles (compute: 1,632,327 + act: 8,968)
#   Exp 9: 1,663,443 cycles (compute: 1,654,475 + act: 8,968)
#   Exp 10: 1,667,450 cycles (compute: 1,658,482 + act: 8,968)
#   Exp 11: 1,662,186 cycles (compute: 1,653,218 + act: 8,968)
#   Exp 12: 1,708,736 cycles (compute: 1,699,768 + act: 8,968)
#   ============================================================================
#   2nd Total (11 experiments): 18,485,493 cycles
#
# 3rd/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,711,811 cycles (compute: 1,702,843 + act: 8,968)
#   Exp 3: 1,712,157 cycles (compute: 1,703,189 + act: 8,968)
#   Exp 4: 1,576,070 cycles (compute: 1,567,102 + act: 8,968)
#   Exp 5: 1,666,706 cycles (compute: 1,657,738 + act: 8,968)
#   Exp 6: 1,602,624 cycles (compute: 1,593,656 + act: 8,968)
#   Exp 7: 1,712,279 cycles (compute: 1,703,311 + act: 8,968)
#   Exp 8: 1,748,566 cycles (compute: 1,739,598 + act: 8,968)
#   Exp 9: 1,758,014 cycles (compute: 1,749,046 + act: 8,968)
#   Exp 10: 1,711,811 cycles (compute: 1,702,843 + act: 8,968)
#   Exp 11: 1,712,157 cycles (compute: 1,703,189 + act: 8,968)
#   Exp 12: 1,576,070 cycles (compute: 1,567,102 + act: 8,968)
#   ============================================================================
#   3rd Total (11 experiments): 18,488,265 cycles
#
# 4th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,718,424 cycles (compute: 1,709,456 + act: 8,968)
#   Exp 3: 1,759,127 cycles (compute: 1,750,159 + act: 8,968)
#   Exp 4: 1,673,407 cycles (compute: 1,664,439 + act: 8,968)
#   Exp 5: 1,643,215 cycles (compute: 1,634,247 + act: 8,968)
#   Exp 6: 1,718,338 cycles (compute: 1,709,370 + act: 8,968)
#   Exp 7: 1,697,041 cycles (compute: 1,688,073 + act: 8,968)
#   Exp 8: 1,661,923 cycles (compute: 1,652,955 + act: 8,968)
#   Exp 9: 1,800,365 cycles (compute: 1,791,397 + act: 8,968)
#   Exp 10: 1,718,424 cycles (compute: 1,709,456 + act: 8,968)
#   Exp 11: 1,759,127 cycles (compute: 1,750,159 + act: 8,968)
#   Exp 12: 1,673,407 cycles (compute: 1,664,439 + act: 8,968)
#   ============================================================================
#   4th Total (11 experiments): 18,822,798 cycles
#
# 5th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,647,469 cycles (compute: 1,638,501 + act: 8,968)
#   Exp 3: 1,620,443 cycles (compute: 1,611,475 + act: 8,968)
#   Exp 4: 1,727,221 cycles (compute: 1,718,253 + act: 8,968)
#   Exp 5: 1,651,710 cycles (compute: 1,642,742 + act: 8,968)
#   Exp 6: 1,697,127 cycles (compute: 1,688,159 + act: 8,968)
#   Exp 7: 1,649,818 cycles (compute: 1,640,850 + act: 8,968)
#   Exp 8: 1,587,710 cycles (compute: 1,578,742 + act: 8,968)
#   Exp 9: 1,672,401 cycles (compute: 1,663,433 + act: 8,968)
#   Exp 10: 1,647,469 cycles (compute: 1,638,501 + act: 8,968)
#   Exp 11: 1,620,443 cycles (compute: 1,611,475 + act: 8,968)
#   Exp 12: 1,727,221 cycles (compute: 1,718,253 + act: 8,968)
#   ============================================================================
#   5th Total (11 experiments): 18,249,032 cycles
#
# 6th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,658,350 cycles (compute: 1,649,382 + act: 8,968)
#   Exp 3: 1,646,929 cycles (compute: 1,637,961 + act: 8,968)
#   Exp 4: 1,596,321 cycles (compute: 1,587,353 + act: 8,968)
#   Exp 5: 1,696,187 cycles (compute: 1,687,219 + act: 8,968)
#   Exp 6: 1,674,308 cycles (compute: 1,665,340 + act: 8,968)
#   Exp 7: 1,615,287 cycles (compute: 1,606,319 + act: 8,968)
#   Exp 8: 1,662,891 cycles (compute: 1,653,923 + act: 8,968)
#   Exp 9: 1,767,130 cycles (compute: 1,758,162 + act: 8,968)
#   Exp 10: 1,658,350 cycles (compute: 1,649,382 + act: 8,968)
#   Exp 11: 1,646,929 cycles (compute: 1,637,961 + act: 8,968)
#   Exp 12: 1,596,321 cycles (compute: 1,587,353 + act: 8,968)
#   ============================================================================
#   6th Total (11 experiments): 18,219,003 cycles
#
# 7th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,572,687 cycles (compute: 1,563,719 + act: 8,968)
#   Exp 3: 1,662,971 cycles (compute: 1,654,003 + act: 8,968)
#   Exp 4: 1,599,759 cycles (compute: 1,590,791 + act: 8,968)
#   Exp 5: 1,782,604 cycles (compute: 1,773,636 + act: 8,968)
#   Exp 6: 1,647,371 cycles (compute: 1,638,403 + act: 8,968)
#   Exp 7: 1,673,218 cycles (compute: 1,664,250 + act: 8,968)
#   Exp 8: 1,687,209 cycles (compute: 1,678,241 + act: 8,968)
#   Exp 9: 1,703,458 cycles (compute: 1,694,490 + act: 8,968)
#   Exp 10: 1,572,687 cycles (compute: 1,563,719 + act: 8,968)
#   Exp 11: 1,662,971 cycles (compute: 1,654,003 + act: 8,968)
#   Exp 12: 1,599,759 cycles (compute: 1,590,791 + act: 8,968)
#   ============================================================================
#   7th Total (11 experiments): 18,164,694 cycles
#
# 8th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,788,953 cycles (compute: 1,779,985 + act: 8,968)
#   Exp 3: 1,735,490 cycles (compute: 1,726,522 + act: 8,968)
#   Exp 4: 1,666,987 cycles (compute: 1,658,019 + act: 8,968)
#   Exp 5: 1,686,781 cycles (compute: 1,677,813 + act: 8,968)
#   Exp 6: 1,757,958 cycles (compute: 1,748,990 + act: 8,968)
#   Exp 7: 1,718,775 cycles (compute: 1,709,807 + act: 8,968)
#   Exp 8: 1,663,405 cycles (compute: 1,654,437 + act: 8,968)
#   Exp 9: 1,731,656 cycles (compute: 1,722,688 + act: 8,968)
#   Exp 10: 1,788,953 cycles (compute: 1,779,985 + act: 8,968)
#   Exp 11: 1,735,490 cycles (compute: 1,726,522 + act: 8,968)
#   Exp 12: 1,666,987 cycles (compute: 1,658,019 + act: 8,968)
#   ============================================================================
#   8th Total (11 experiments): 18,941,435 cycles
#
# 9th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,721,248 cycles (compute: 1,712,280 + act: 8,968)
#   Exp 3: 1,754,359 cycles (compute: 1,745,391 + act: 8,968)
#   Exp 4: 1,669,747 cycles (compute: 1,660,779 + act: 8,968)
#   Exp 5: 1,712,673 cycles (compute: 1,703,705 + act: 8,968)
#   Exp 6: 1,687,885 cycles (compute: 1,678,917 + act: 8,968)
#   Exp 7: 1,696,651 cycles (compute: 1,687,683 + act: 8,968)
#   Exp 8: 1,665,156 cycles (compute: 1,656,188 + act: 8,968)
#   Exp 9: 1,758,302 cycles (compute: 1,749,334 + act: 8,968)
#   Exp 10: 1,721,248 cycles (compute: 1,712,280 + act: 8,968)
#   Exp 11: 1,754,359 cycles (compute: 1,745,391 + act: 8,968)
#   Exp 12: 1,669,747 cycles (compute: 1,660,779 + act: 8,968)
#   ============================================================================
#   9th Total (11 experiments): 18,811,375 cycles
#
# 10th/:
# --------------------------------------------------------------------------------
#   Exp 2: 1,657,842 cycles (compute: 1,648,874 + act: 8,968)
#   Exp 3: 1,641,924 cycles (compute: 1,632,956 + act: 8,968)
#   Exp 4: 1,721,121 cycles (compute: 1,712,153 + act: 8,968)
#   Exp 5: 1,620,773 cycles (compute: 1,611,805 + act: 8,968)
#   Exp 6: 1,728,303 cycles (compute: 1,719,335 + act: 8,968)
#   Exp 7: 1,664,080 cycles (compute: 1,655,112 + act: 8,968)
#   Exp 8: 1,643,562 cycles (compute: 1,634,594 + act: 8,968)
#   Exp 9: 1,663,210 cycles (compute: 1,654,242 + act: 8,968)
#   Exp 10: 1,657,842 cycles (compute: 1,648,874 + act: 8,968)
#   Exp 11: 1,641,924 cycles (compute: 1,632,956 + act: 8,968)
#   Exp 12: 1,721,121 cycles (compute: 1,712,153 + act: 8,968)
#   ============================================================================
#   10th Total (11 experiments): 18,361,702 cycles
#
# ================================================================================
# Numbered Folder Totals
# ================================================================================
# Numbered Folder  Experiments Processed  Folder Total
#             1st                     11      18308898
#             2nd                     11      18485493
#             3rd                     11      18488265
#             4th                     11      18822798
#             5th                     11      18249032
#             6th                     11      18219003
#             7th                     11      18164694
#             8th                     11      18941435
#             9th                     11      18811375
#            10th                     11      18361702
#
# ================================================================================
# GRAND TOTAL (All PIM experiments): 184,852,695 cycles
# ================================================================================
#   Numbered Folder  Experiments Processed  Folder Total
# 0             1st                     11      18308898
# 1             2nd                     11      18485493
# 2             3rd                     11      18488265
# 3             4th                     11      18822798
# 4             5th                     11      18249032
# 5             6th                     11      18219003
# 6             7th                     11      18164694
# 7             8th                     11      18941435
# 8             9th                     11      18811375
# 9            10th                     11      18361702

# %%
import pandas as pd
import os
import re
import math

# Base directory
base_dir = 'Decoder-BS64-switch'

# Numbered folders to process
numbered_folders = ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th']

# Store results for each experiment
all_experiment_results = []
numbered_folder_totals = []
grand_total = 0

print("="*80)
print("HYBRID MODE Analysis (Top H on NPU, Rest on PIM) - Decoder-BS16")
print("="*80)
print()

# Process each numbered folder
for folder_name in numbered_folders:
    folder_path = os.path.join(base_dir, folder_name)
    
    if not os.path.exists(folder_path):
        print(f"⚠ {folder_name}/ not found, skipping...")
        continue
    
    print(f"\n{'='*80}")
    print(f"Processing: {folder_name}/")
    print('='*80)
    
    folder_total_cycles = 0
    experiment_count = 0
    
    # Process experiment folders 2-26 (or however many exist)
    for exp_num in range(2, 27):
        # Determine which layer file to use (cycling through 2-9)
        layer_num = ((exp_num - 2) % 8) + 2
        layer_file = os.path.join(folder_path, f'layer{layer_num}.txt')
        
        npu_txt = os.path.join(folder_path, 'npu', str(exp_num), 'SA_stage_E.txt')
        pim_txt = os.path.join(folder_path, 'pim', str(exp_num), 'SA_stage_E.txt')
        
        # Check if files exist
        if not os.path.exists(layer_file):
            print(f"  Exp {exp_num}: layer{layer_num}.txt not found, skipping...")
            continue
        if not os.path.exists(npu_txt):
            print(f"  Exp {exp_num}: NPU file not found, skipping...")
            continue
        if not os.path.exists(pim_txt):
            print(f"  Exp {exp_num}: PIM file not found, skipping...")
            continue
    
                # Read layer file to identify all active experts and top 4
        with open(layer_file, 'r') as f:
            layer_content = f.read()
        
        # Parse layer file to get all experts with usage > 0
        all_active_experts = []
        for line in layer_content.split('\n'):
            # Look for lines with expert numbers and token count
            match = re.search(r'Expert\s+(\d+)\s+(\d+)', line)
            if match:
                expert_num = int(match.group(1))
                token_count = int(match.group(2))
                # Only count experts with at least 1 token
                if token_count > 0:
                    all_active_experts.append(expert_num)
        
        total_active_experts = len(all_active_experts)
        
        if total_active_experts == 0:
            print(f"  Exp {exp_num}: No active experts found in layer{layer_num}.txt, skipping...")
            continue
        
        # Calculate dynamic NPU allocation based on bandwidth ratio
        # Formula: num_on_npu = ceil(0.05882 × total_active_experts)
        num_experts_on_npu = math.ceil(0.05882 * total_active_experts)
        
        # Ensure at least 1 expert on NPU, and not more than total active
        num_experts_on_npu = max(1, min(num_experts_on_npu, total_active_experts))
        
        # Top N experts go to NPU (N is dynamically calculated)
        top_npu_experts = all_active_experts[:num_experts_on_npu]
        
        # Calculate remaining experts on PIM
        num_experts_on_pim = total_active_experts - num_experts_on_npu
        
        # print(f"  Exp {exp_num} (using layer{layer_num}.txt):")
        # print(f"    Top 4 experts: {top_4_experts}")
    
        # Read NPU file and extract data for top N experts
        with open(npu_txt, 'r') as f:
            npu_content = f.read()
        
        npu_param_load_sum = 0
        last_expert_total_compute = 0
        
        for line in npu_content.split('\n'):
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'NPU Expert' in line or 'Decoder' in line:
                continue
            
            parts = line.split()
            if len(parts) >= 6:
                try:
                    expert_num = int(parts[0])
                    if expert_num in top_npu_experts:
                        param_load = int(parts[1])
                        total_compute = int(parts[5])
                        npu_param_load_sum += param_load
                        
                        # If this is the last expert in NPU group (slowest)
                        if expert_num == top_npu_experts[-1]:
                            last_expert_total_compute = total_compute
                except (ValueError, IndexError):
                    continue
    
        # Read PIM file and extract data for remaining experts
        with open(pim_txt, 'r') as f:
            pim_content = f.read()
        
        # Extract activation movements
        activation_1 = 0
        activation_2 = 0
        
        for line in pim_content.split('\n'):
            if 'activation_movement_1' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_1 = int(float(match.group(1)))
            elif 'activation_movement_2' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_2 = int(float(match.group(1)))
        
        # Extract total compute for remaining experts (not in top 4)
        pim_total_compute_sum = 0
        
        for line in pim_content.split('\n'):
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'Note:' in line or 'Activation' in line or '-' in line[:3] or 'PIM Expert' in line or 'Decoder' in line or 'BS' in line:
                continue
            
            parts = line.split()
            if len(parts) >= 5:
                try:
                    expert_num = int(parts[0])
                    # Only include experts NOT in top N (NPU group)
                    if expert_num not in top_npu_experts:
                        total_compute = int(parts[4])
                        pim_total_compute_sum += total_compute
                except (ValueError, IndexError):
                    continue
    
        # Calculate experiment total (NPU and PIM run in PARALLEL, so take MAX)
        npu_time = npu_param_load_sum + last_expert_total_compute
        pim_time = pim_total_compute_sum + activation_1 + activation_2
        exp_total = max(npu_time, pim_time)
        
        folder_total_cycles += exp_total
        experiment_count += 1
        
        # Store experiment result
        all_experiment_results.append({
            'Numbered Folder': folder_name,
            'Experiment': exp_num,
            'Layer File': f'layer{layer_num}.txt',
            'Total Active': total_active_experts,
            'Experts on NPU': num_experts_on_npu,
            'Experts on PIM': num_experts_on_pim,
            'Top NPU Experts': str(top_npu_experts),
            'NPU param_load': npu_param_load_sum,
            'Last expert compute': last_expert_total_compute,
            'PIM compute': pim_total_compute_sum,
            'Activations': activation_1 + activation_2,
            'Experiment Total': exp_total
        })
        
        # Print detailed result
        bottleneck = "NPU" if npu_time >= pim_time else "PIM"
        
        print(f"\n  Experiment {exp_num} (using layer{layer_num}.txt):")
        print(f"    Active experts: {total_active_experts} total → {num_experts_on_npu} on NPU, {num_experts_on_pim} on PIM")
        print(f"    Top {num_experts_on_npu} experts (NPU): {top_npu_experts}")
        print(f"    NPU Time (parallel with PIM):")
        print(f"      - Param load (top {num_experts_on_npu}): {npu_param_load_sum:,} cycles")
        print(f"      - Last expert (#{num_experts_on_npu}) compute: {last_expert_total_compute:,} cycles")
        print(f"      - NPU Total: {npu_time:,} cycles")
        print(f"    PIM Time (parallel with NPU):")
        print(f"      - Total compute ({num_experts_on_pim} experts): {pim_total_compute_sum:,} cycles")
        print(f"      - Activation 1: {activation_1:,} cycles")
        print(f"      - Activation 2: {activation_2:,} cycles")
        print(f"      - PIM Total: {pim_time:,} cycles")
        print(f"    TOTAL (MAX): {exp_total:,} cycles [{bottleneck} is bottleneck]")
    
    # Store numbered folder total
    if experiment_count > 0:
        numbered_folder_totals.append({
            'Numbered Folder': folder_name,
            'Experiments Processed': experiment_count,
            'Folder Total': folder_total_cycles
        })
        grand_total += folder_total_cycles
        
        print(f"  {'='*76}")
        print(f"  {folder_name} Total ({experiment_count} experiments): {folder_total_cycles:,} cycles")

# Create summary DataFrames
experiments_df = pd.DataFrame(all_experiment_results)
folders_df = pd.DataFrame(numbered_folder_totals)

print("\n" + "="*80)
print("Numbered Folder Totals")
print("="*80)
print(folders_df.to_string(index=False))

print("\n" + "="*80)
print(f"GRAND TOTAL (Hybrid Mode - All experiments): {grand_total:,} cycles")
print("="*80)

# Display folders DataFrame
folders_df
# Out:
# ================================================================================
# HYBRID MODE Analysis (Top H on NPU, Rest on PIM) - Decoder-BS16
# ================================================================================
#
#
# ================================================================================
# Processing: 1st/
# ================================================================================
#
#   Experiment 2 (using layer2.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [20, 12, 26]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,331 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,075 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 3 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [62, 31, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,446 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 651,112 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,856 cycles
#     TOTAL (MAX): 1,071,446 cycles [NPU is bottleneck]
#
#   Experiment 4 (using layer4.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [32, 46]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,196 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,940 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#
#   Experiment 5 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [51, 36, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 594,823 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,567 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 6 (using layer6.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [12, 5, 23]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,129 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 638,873 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 7 (using layer7.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [34, 10, 17]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 688,229 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,973 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 8 (using layer8.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [22, 14]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 342 cycles
#       - NPU Total: 714,454 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,112 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,856 cycles
#     TOTAL (MAX): 714,454 cycles [NPU is bottleneck]
#
#   Experiment 9 (using layer9.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [49, 23, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,316 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 687,964 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,708 cycles
#     TOTAL (MAX): 1,071,316 cycles [NPU is bottleneck]
#
#   Experiment 10 (using layer2.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [20, 12, 26]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,331 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,075 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 11 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [62, 31, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,446 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 651,112 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,856 cycles
#     TOTAL (MAX): 1,071,446 cycles [NPU is bottleneck]
#
#   Experiment 12 (using layer4.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [32, 46]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,196 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,940 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#
#   Experiment 13 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [51, 36, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 594,823 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,567 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 14 (using layer6.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [12, 5, 23]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,129 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 638,873 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 15 (using layer7.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [34, 10, 17]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 688,229 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,973 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 16 (using layer8.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [22, 14]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 342 cycles
#       - NPU Total: 714,454 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,112 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,856 cycles
#     TOTAL (MAX): 714,454 cycles [NPU is bottleneck]
#
#   Experiment 17 (using layer9.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [49, 23, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,316 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 687,964 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,708 cycles
#     TOTAL (MAX): 1,071,316 cycles [NPU is bottleneck]
#
#   Experiment 18 (using layer2.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [20, 12, 26]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,331 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,075 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 19 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [62, 31, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,446 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 651,112 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,856 cycles
#     TOTAL (MAX): 1,071,446 cycles [NPU is bottleneck]
#
#   Experiment 20 (using layer4.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [32, 46]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,196 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,940 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#
#   Experiment 21 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [51, 36, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 594,823 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,567 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 22 (using layer6.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [12, 5, 23]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,129 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 638,873 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 23 (using layer7.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [34, 10, 17]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 688,229 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,973 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 24 (using layer8.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [22, 14]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 342 cycles
#       - NPU Total: 714,454 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,112 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,856 cycles
#     TOTAL (MAX): 714,454 cycles [NPU is bottleneck]
#
#   Experiment 25 (using layer9.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [49, 23, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,316 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 687,964 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,708 cycles
#     TOTAL (MAX): 1,071,316 cycles [NPU is bottleneck]
#
#   Experiment 26 (using layer2.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [20, 12, 26]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,331 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,075 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#   ============================================================================
#   1st Total (25 experiments): 24,643,283 cycles
#
# ================================================================================
# Processing: 2nd/
# ================================================================================
#
#   Experiment 2 (using layer2.txt):
#     Active experts: 32 total → 2 on NPU, 30 on PIM
#     Top 2 experts (NPU): [9, 31]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (30 experts): 558,158 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,902 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#
#   Experiment 3 (using layer3.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [37, 60, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,380 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,179 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 675,923 cycles
#     TOTAL (MAX): 1,071,380 cycles [NPU is bottleneck]
#
#   Experiment 4 (using layer4.txt):
#     Active experts: 31 total → 2 on NPU, 29 on PIM
#     Top 2 experts (NPU): [14, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (29 experts): 557,774 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,518 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 5 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [20, 0, 9]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,398 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 602,142 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 6 (using layer6.txt):
#     Active experts: 41 total → 3 on NPU, 38 on PIM
#     Top 3 experts (NPU): [30, 36, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,508 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (38 experts): 706,797 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 713,541 cycles
#     TOTAL (MAX): 1,071,508 cycles [NPU is bottleneck]
#
#   Experiment 7 (using layer7.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 25]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,314 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,058 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 8 (using layer8.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [22, 17, 46]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,415 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,159 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 9 (using layer9.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [12, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 713,984 cycles
#       - Last expert (#2) compute: 343 cycles
#       - NPU Total: 714,327 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,543 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,287 cycles
#     TOTAL (MAX): 714,327 cycles [NPU is bottleneck]
#
#   Experiment 10 (using layer2.txt):
#     Active experts: 32 total → 2 on NPU, 30 on PIM
#     Top 2 experts (NPU): [9, 31]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (30 experts): 558,158 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,902 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#
#   Experiment 11 (using layer3.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [37, 60, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,380 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,179 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 675,923 cycles
#     TOTAL (MAX): 1,071,380 cycles [NPU is bottleneck]
#
#   Experiment 12 (using layer4.txt):
#     Active experts: 31 total → 2 on NPU, 29 on PIM
#     Top 2 experts (NPU): [14, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (29 experts): 557,774 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,518 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 13 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [20, 0, 9]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,398 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 602,142 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 14 (using layer6.txt):
#     Active experts: 41 total → 3 on NPU, 38 on PIM
#     Top 3 experts (NPU): [30, 36, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,508 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (38 experts): 706,797 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 713,541 cycles
#     TOTAL (MAX): 1,071,508 cycles [NPU is bottleneck]
#
#   Experiment 15 (using layer7.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 25]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,314 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,058 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 16 (using layer8.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [22, 17, 46]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,415 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,159 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 17 (using layer9.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [12, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 713,984 cycles
#       - Last expert (#2) compute: 343 cycles
#       - NPU Total: 714,327 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,543 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,287 cycles
#     TOTAL (MAX): 714,327 cycles [NPU is bottleneck]
#
#   Experiment 18 (using layer2.txt):
#     Active experts: 32 total → 2 on NPU, 30 on PIM
#     Top 2 experts (NPU): [9, 31]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (30 experts): 558,158 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,902 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#
#   Experiment 19 (using layer3.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [37, 60, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,380 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,179 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 675,923 cycles
#     TOTAL (MAX): 1,071,380 cycles [NPU is bottleneck]
#
#   Experiment 20 (using layer4.txt):
#     Active experts: 31 total → 2 on NPU, 29 on PIM
#     Top 2 experts (NPU): [14, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (29 experts): 557,774 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,518 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 21 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [20, 0, 9]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,398 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 602,142 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 22 (using layer6.txt):
#     Active experts: 41 total → 3 on NPU, 38 on PIM
#     Top 3 experts (NPU): [30, 36, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 340 cycles
#       - NPU Total: 1,071,508 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (38 experts): 706,797 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 713,541 cycles
#     TOTAL (MAX): 1,071,508 cycles [NPU is bottleneck]
#
#   Experiment 23 (using layer7.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 25]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,314 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,058 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 24 (using layer8.txt):
#     Active experts: 39 total → 3 on NPU, 36 on PIM
#     Top 3 experts (NPU): [22, 17, 46]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (36 experts): 669,415 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 676,159 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 25 (using layer9.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [12, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 713,984 cycles
#       - Last expert (#2) compute: 343 cycles
#       - NPU Total: 714,327 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,543 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,287 cycles
#     TOTAL (MAX): 714,327 cycles [NPU is bottleneck]
#
#   Experiment 26 (using layer2.txt):
#     Active experts: 32 total → 2 on NPU, 30 on PIM
#     Top 2 experts (NPU): [9, 31]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 341 cycles
#       - NPU Total: 714,453 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (30 experts): 558,158 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 564,902 cycles
#     TOTAL (MAX): 714,453 cycles [NPU is bottleneck]
#   ============================================================================
#   2nd Total (25 experiments): 22,145,637 cycles
#
# ================================================================================
# Processing: 3rd/
# ================================================================================
#
#   Experiment 2 (using layer2.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [18, 36, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,140 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,884 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 3 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [55, 41, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,932 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,676 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 4 (using layer4.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [23, 6, 3]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 343 cycles
#       - NPU Total: 1,071,575 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,543 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,287 cycles
#     TOTAL (MAX): 1,071,575 cycles [NPU is bottleneck]
#
#   Experiment 5 (using layer5.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [25, 18, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,573 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 651,047 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,791 cycles
#     TOTAL (MAX): 1,071,573 cycles [NPU is bottleneck]
#
#   Experiment 6 (using layer6.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [27, 36, 19]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,717 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,461 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 7 (using layer7.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [44, 34, 54]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 633 cycles
#       - NPU Total: 1,071,673 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,583 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,327 cycles
#     TOTAL (MAX): 1,071,673 cycles [NPU is bottleneck]
#
#   Experiment 8 (using layer8.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [15, 34]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 342 cycles
#       - NPU Total: 714,454 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,178 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,922 cycles
#     TOTAL (MAX): 714,454 cycles [NPU is bottleneck]
#
#   Experiment 9 (using layer9.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [14, 16, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,941 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,685 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 10 (using layer2.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [18, 36, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,140 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,884 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 11 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [55, 41, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,932 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,676 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 12 (using layer4.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [23, 6, 3]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 343 cycles
#       - NPU Total: 1,071,575 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,543 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,287 cycles
#     TOTAL (MAX): 1,071,575 cycles [NPU is bottleneck]
#
#   Experiment 13 (using layer5.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [25, 18, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,573 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 651,047 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,791 cycles
#     TOTAL (MAX): 1,071,573 cycles [NPU is bottleneck]
#
#   Experiment 14 (using layer6.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [27, 36, 19]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,717 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,461 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 15 (using layer7.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [44, 34, 54]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 633 cycles
#       - NPU Total: 1,071,673 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,583 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,327 cycles
#     TOTAL (MAX): 1,071,673 cycles [NPU is bottleneck]
#
#   Experiment 16 (using layer8.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [15, 34]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 342 cycles
#       - NPU Total: 714,454 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,178 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,922 cycles
#     TOTAL (MAX): 714,454 cycles [NPU is bottleneck]
#
#   Experiment 17 (using layer9.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [14, 16, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,941 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,685 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 18 (using layer2.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [18, 36, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,140 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,884 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 19 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [55, 41, 60]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,932 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,676 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 20 (using layer4.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [23, 6, 3]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 343 cycles
#       - NPU Total: 1,071,575 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,543 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,287 cycles
#     TOTAL (MAX): 1,071,575 cycles [NPU is bottleneck]
#
#   Experiment 21 (using layer5.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [25, 18, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,573 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 651,047 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,791 cycles
#     TOTAL (MAX): 1,071,573 cycles [NPU is bottleneck]
#
#   Experiment 22 (using layer6.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [27, 36, 19]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,717 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,461 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 23 (using layer7.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [44, 34, 54]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 633 cycles
#       - NPU Total: 1,071,673 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,583 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,327 cycles
#     TOTAL (MAX): 1,071,673 cycles [NPU is bottleneck]
#
#   Experiment 24 (using layer8.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [15, 34]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,112 cycles
#       - Last expert (#2) compute: 342 cycles
#       - NPU Total: 714,454 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,178 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,922 cycles
#     TOTAL (MAX): 714,454 cycles [NPU is bottleneck]
#
#   Experiment 25 (using layer9.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [14, 16, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,941 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,685 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 26 (using layer2.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [18, 36, 12]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,140 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,884 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#   ============================================================================
#   3rd Total (25 experiments): 25,716,101 cycles
#
# ================================================================================
# Processing: 4th/
# ================================================================================
#
#   Experiment 2 (using layer2.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [16, 21]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,244 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,988 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 3 (using layer3.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [22, 35, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,244 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 638,988 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 4 (using layer4.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [7, 47, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,895 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,639 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 5 (using layer5.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [0, 42, 45]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,577 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 639,321 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 6 (using layer6.txt):
#     Active experts: 41 total → 3 on NPU, 38 on PIM
#     Top 3 experts (NPU): [42, 7, 22]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (38 experts): 706,502 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 713,246 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 7 (using layer7.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [28, 62, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,912 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,254 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,205 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,949 cycles
#     TOTAL (MAX): 1,071,254 cycles [NPU is bottleneck]
#
#   Experiment 8 (using layer8.txt):
#     Active experts: 40 total → 3 on NPU, 37 on PIM
#     Top 3 experts (NPU): [11, 10, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,381 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (37 experts): 688,193 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 694,937 cycles
#     TOTAL (MAX): 1,071,381 cycles [NPU is bottleneck]
#
#   Experiment 9 (using layer9.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [1, 52, 6]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,296 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,638 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 631,922 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 638,666 cycles
#     TOTAL (MAX): 1,071,638 cycles [NPU is bottleneck]
#
#   Experiment 10 (using layer2.txt):
#     Active experts: 34 total → 2 on NPU, 32 on PIM
#     Top 2 experts (NPU): [16, 21]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,048 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,681 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,244 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,988 cycles
#     TOTAL (MAX): 714,681 cycles [NPU is bottleneck]
#
#   Experiment 11 (using layer3.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [22, 35, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,040 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,382 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,244 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 638,988 cycles
#     TOTAL (MAX): 1,071,382 cycles [NPU is bottleneck]
#
#   Experiment 12 (using layer4.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [7, 47, 2]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,895 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,639 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#
#   Experiment 13 (using layer5.txt):
#     Active experts: 37 total → 3 on NPU, 34 on PIM
#     Top 3 experts (NPU): [0, 42, 45]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (34 experts): 632,577 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 639,321 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 14 (using layer6.txt):
#     Active experts: 41 total → 3 on NPU, 38 on PIM
#     Top 3 experts (NPU): [42, 7, 22]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (38 experts): 706,502 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 713,246 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 15 (using layer7.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [28, 62, 0]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,912 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,254 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,205 cycles
#       - Activation 1: 3,379 cycles
# ...
#       - NPU Total: 1,071,253 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,736 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,480 cycles
#     TOTAL (MAX): 1,071,253 cycles [NPU is bottleneck]
#
#   Experiment 26 (using layer2.txt):
#     Active experts: 41 total → 3 on NPU, 38 on PIM
#     Top 3 experts (NPU): [1, 23, 28]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,168 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,509 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (38 experts): 707,051 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 713,795 cycles
#     TOTAL (MAX): 1,071,509 cycles [NPU is bottleneck]
#   ============================================================================
#   9th Total (25 experiments): 23,573,288 cycles
#
# ================================================================================
# Processing: 10th/
# ================================================================================
#
#   Experiment 2 (using layer2.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 18]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,176 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,809 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,370 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,114 cycles
#     TOTAL (MAX): 714,809 cycles [NPU is bottleneck]
#
#   Experiment 3 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [58, 21, 9]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,925 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,669 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 4 (using layer4.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [14, 15, 37]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,574 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,824 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,568 cycles
#     TOTAL (MAX): 1,071,574 cycles [NPU is bottleneck]
#
#   Experiment 5 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [17, 20, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,574 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,453 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 602,197 cycles
#     TOTAL (MAX): 1,071,574 cycles [NPU is bottleneck]
#
#   Experiment 6 (using layer6.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 713,984 cycles
#       - Last expert (#2) compute: 343 cycles
#       - NPU Total: 714,327 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,741 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,485 cycles
#     TOTAL (MAX): 714,327 cycles [NPU is bottleneck]
#
#   Experiment 7 (using layer7.txt):
#     Active experts: 42 total → 3 on NPU, 39 on PIM
#     Top 3 experts (NPU): [2, 43, 51]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (39 experts): 725,395 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 732,139 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 8 (using layer8.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [22, 24, 14]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,196 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,940 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 9 (using layer9.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [42, 48, 49]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,912 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,254 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,491 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,235 cycles
#     TOTAL (MAX): 1,071,254 cycles [NPU is bottleneck]
#
#   Experiment 10 (using layer2.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 18]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,176 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,809 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,370 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,114 cycles
#     TOTAL (MAX): 714,809 cycles [NPU is bottleneck]
#
#   Experiment 11 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [58, 21, 9]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,925 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,669 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 12 (using layer4.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [14, 15, 37]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,574 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,824 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,568 cycles
#     TOTAL (MAX): 1,071,574 cycles [NPU is bottleneck]
#
#   Experiment 13 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [17, 20, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,574 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,453 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 602,197 cycles
#     TOTAL (MAX): 1,071,574 cycles [NPU is bottleneck]
#
#   Experiment 14 (using layer6.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 713,984 cycles
#       - Last expert (#2) compute: 343 cycles
#       - NPU Total: 714,327 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,741 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,485 cycles
#     TOTAL (MAX): 714,327 cycles [NPU is bottleneck]
#
#   Experiment 15 (using layer7.txt):
#     Active experts: 42 total → 3 on NPU, 39 on PIM
#     Top 3 experts (NPU): [2, 43, 51]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (39 experts): 725,395 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 732,139 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 16 (using layer8.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [22, 24, 14]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,196 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,940 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 17 (using layer9.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [42, 48, 49]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,912 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,254 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,491 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,235 cycles
#     TOTAL (MAX): 1,071,254 cycles [NPU is bottleneck]
#
#   Experiment 18 (using layer2.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 18]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,176 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,809 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,370 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,114 cycles
#     TOTAL (MAX): 714,809 cycles [NPU is bottleneck]
#
#   Experiment 19 (using layer3.txt):
#     Active experts: 38 total → 3 on NPU, 35 on PIM
#     Top 3 experts (NPU): [58, 21, 9]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (35 experts): 650,925 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 657,669 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 20 (using layer4.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [14, 15, 37]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,574 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,824 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,568 cycles
#     TOTAL (MAX): 1,071,574 cycles [NPU is bottleneck]
#
#   Experiment 21 (using layer5.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [17, 20, 39]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,232 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,574 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,453 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 602,197 cycles
#     TOTAL (MAX): 1,071,574 cycles [NPU is bottleneck]
#
#   Experiment 22 (using layer6.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 27]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 713,984 cycles
#       - Last expert (#2) compute: 343 cycles
#       - NPU Total: 714,327 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,741 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,485 cycles
#     TOTAL (MAX): 714,327 cycles [NPU is bottleneck]
#
#   Experiment 23 (using layer7.txt):
#     Active experts: 42 total → 3 on NPU, 39 on PIM
#     Top 3 experts (NPU): [2, 43, 51]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,976 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,317 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (39 experts): 725,395 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 732,139 cycles
#     TOTAL (MAX): 1,071,317 cycles [NPU is bottleneck]
#
#   Experiment 24 (using layer8.txt):
#     Active experts: 35 total → 3 on NPU, 32 on PIM
#     Top 3 experts (NPU): [22, 24, 14]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,071,104 cycles
#       - Last expert (#3) compute: 341 cycles
#       - NPU Total: 1,071,445 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (32 experts): 595,196 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 601,940 cycles
#     TOTAL (MAX): 1,071,445 cycles [NPU is bottleneck]
#
#   Experiment 25 (using layer9.txt):
#     Active experts: 36 total → 3 on NPU, 33 on PIM
#     Top 3 experts (NPU): [42, 48, 49]
#     NPU Time (parallel with PIM):
#       - Param load (top 3): 1,070,912 cycles
#       - Last expert (#3) compute: 342 cycles
#       - NPU Total: 1,071,254 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (33 experts): 613,491 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 620,235 cycles
#     TOTAL (MAX): 1,071,254 cycles [NPU is bottleneck]
#
#   Experiment 26 (using layer2.txt):
#     Active experts: 33 total → 2 on NPU, 31 on PIM
#     Top 2 experts (NPU): [2, 18]
#     NPU Time (parallel with PIM):
#       - Param load (top 2): 714,176 cycles
#       - Last expert (#2) compute: 633 cycles
#       - NPU Total: 714,809 cycles
#     PIM Time (parallel with NPU):
#       - Total compute (31 experts): 576,370 cycles
#       - Activation 1: 3,379 cycles
#       - Activation 2: 3,365 cycles
#       - PIM Total: 583,114 cycles
#     TOTAL (MAX): 714,809 cycles [NPU is bottleneck]
#   ============================================================================
#   10th Total (25 experiments): 24,288,044 cycles
#
# ================================================================================
# Numbered Folder Totals
# ================================================================================
# Numbered Folder  Experiments Processed  Folder Total
#             1st                     25      24643283
#             2nd                     25      22145637
#             3rd                     25      25716101
#             4th                     25      25358502
#             5th                     25      24644307
#             6th                     25      26786390
#             7th                     25      25359431
#             8th                     25      25715270
#             9th                     25      23573288
#            10th                     25      24288044
#
# ================================================================================
# GRAND TOTAL (Hybrid Mode - All experiments): 248,230,253 cycles
# ================================================================================
#   Numbered Folder  Experiments Processed  Folder Total
# 0             1st                     25      24643283
# 1             2nd                     25      22145637
# 2             3rd                     25      25716101
# 3             4th                     25      25358502
# 4             5th                     25      24644307
# 5             6th                     25      26786390
# 6             7th                     25      25359431
# 7             8th                     25      25715270
# 8             9th                     25      23573288
# 9            10th                     25      24288044

# %%
import pandas as pd
import os
import re

# Base directory
base_dir = 'Decoder-BS32'

print("="*80)
print("INCREMENTAL OPTIMIZATION Analysis - Decoder-BS16")
print("Finding optimal number of experts to move from PIM to NPU")
print("="*80)
print()

# Numbered folders to process
numbered_folders = ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th']

# Store results
all_folder_results = []
optimization_summary = []
numbered_folder_summaries = []

# Process each numbered folder
for folder_name in numbered_folders:
    folder_path = os.path.join(base_dir, folder_name)
    
    if not os.path.exists(folder_path):
        print(f"⚠ {folder_name}/ not found, skipping...")
        continue
    
    print(f"\n{'='*80}")
    print(f"Processing: {folder_name}/")
    print('='*80)
    print()
    
    folder_optimal_total = 0
    experiments_processed = 0
    
    # Process experiment folders 2-26
    for exp_num in range(2, 10):
        # Determine which layer file to use (cycling through 2-9)
        layer_num = ((exp_num - 2) % 8) + 2
        layer_file = os.path.join(folder_path, f'layer{layer_num}.txt')
        
        npu_txt = os.path.join(folder_path, 'npu', str(exp_num), 'SA_stage_E.txt')
        pim_txt = os.path.join(folder_path, 'pim', str(exp_num), 'SA_stage_E.txt')
        
        # Check if files exist
        if not os.path.exists(layer_file):
            continue
        if not os.path.exists(npu_txt):
            continue
        if not os.path.exists(pim_txt):
            continue
        
        # Read layer file to get ordered list of experts (top to bottom by usage)
        with open(layer_file, 'r') as f:
            layer_content = f.read()
        
        expert_order = []
        for line in layer_content.split('\n'):
            match = re.search(r'Expert\s+(\d+)\s+(\d+)', line)
            if match:
                expert_num = int(match.group(1))
                token_count = int(match.group(2))
                # Only include active experts (token_count > 0)
                if token_count > 0:
                    expert_order.append(expert_num)
        
        total_active_experts = len(expert_order)
        
        if total_active_experts == 0:
            continue
        
        # Read NPU data
        with open(npu_txt, 'r') as f:
            npu_content = f.read()
        
        npu_data = {}
        for line in npu_content.split('\n'):
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'NPU Expert' in line or 'Decoder' in line:
                continue
            
            parts = line.split()
            if len(parts) >= 6:
                try:
                    expert_num = int(parts[0])
                    param_load = int(parts[1])
                    total_compute = int(parts[5])
                    npu_data[expert_num] = {'param_load': param_load, 'total_compute': total_compute}
                except (ValueError, IndexError):
                    continue
        
        # Read PIM data
        with open(pim_txt, 'r') as f:
            pim_content = f.read()
        
        # Extract activation movements
        activation_1 = 0
        activation_2 = 0
        
        for line in pim_content.split('\n'):
            if 'activation_movement_1' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_1 = int(float(match.group(1)))
            elif 'activation_movement_2' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_2 = int(float(match.group(1)))
        
        pim_data = {}
        for line in pim_content.split('\n'):
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'Note:' in line or 'Activation' in line or '-' in line[:3] or 'PIM Expert' in line or 'Decoder' in line or 'BS' in line:
                continue
            
            parts = line.split()
            if len(parts) >= 5:
                try:
                    expert_num = int(parts[0])
                    total_compute = int(parts[4])
                    pim_data[expert_num] = {'total_compute': total_compute}
                except (ValueError, IndexError):
                    continue
        
        # Now test configurations from 0 to total_active_experts
        configurations = []
        
        for num_on_npu in range(0, total_active_experts + 1):
            if num_on_npu == 0:
                # All on PIM
                npu_time = 0
                pim_compute = sum(pim_data[exp]['total_compute'] for exp in expert_order if exp in pim_data)
                pim_time = pim_compute + activation_1 + activation_2
                total_cycles = pim_time
            else:
                # Top num_on_npu experts on NPU, rest on PIM
                top_experts = expert_order[:num_on_npu]
                remaining_experts = expert_order[num_on_npu:]
                
                # NPU: param_load of top experts + total compute of last expert in top group
                npu_param_load = sum(npu_data[exp]['param_load'] for exp in top_experts if exp in npu_data)
                npu_last_compute = npu_data[top_experts[-1]]['total_compute'] if top_experts[-1] in npu_data else 0
                npu_time = npu_param_load + npu_last_compute
                
                # PIM: total compute of remaining experts
                pim_compute = sum(pim_data[exp]['total_compute'] for exp in remaining_experts if exp in pim_data)
                
                if num_on_npu == total_active_experts:
                    # All on NPU, no PIM usage
                    pim_time = 0
                else:
                    # PIM is active
                    pim_time = pim_compute + activation_1 + activation_2
                
                # Total = MAX because NPU and PIM run simultaneously (PARALLEL)
                total_cycles = max(npu_time, pim_time)
            
            configurations.append({
                'Numbered Folder': folder_name,
                'Experiment': exp_num,
                'Experts on NPU': num_on_npu,
                'NPU Time': npu_time,
                'PIM Time': pim_time,
                'Total Cycles': total_cycles
            })
        
        # Find optimal configuration (minimum total cycles)
        min_config = min(configurations, key=lambda x: x['Total Cycles'])
        
        print(f"  Exp {exp_num} (layer{layer_num}.txt, {total_active_experts} active experts):")
        print(f"    Optimal: {min_config['Experts on NPU']} experts on NPU")
        print(f"    NPU Time: {min_config['NPU Time']:,} | PIM Time: {min_config['PIM Time']:,}")
        print(f"    Minimum Total (MAX): {min_config['Total Cycles']:,} cycles")
        
        # Store all configurations for this experiment
        all_folder_results.extend(configurations)
        
        # Store optimization summary for this experiment
        optimization_summary.append({
            'Numbered Folder': folder_name,
            'Experiment': exp_num,
            'Layer File': f'layer{layer_num}.txt',
            'Total Active Experts': total_active_experts,
            'Optimal Experts on NPU': min_config['Experts on NPU'],
            'NPU Time': min_config['NPU Time'],
            'PIM Time': min_config['PIM Time'],
            'Optimal Total Cycles': min_config['Total Cycles']
        })
        
        folder_optimal_total += min_config['Total Cycles']
        experiments_processed += 1
    
    # Store numbered folder summary
    if experiments_processed > 0:
        numbered_folder_summaries.append({
            'Numbered Folder': folder_name,
            'Experiments Processed': experiments_processed,
            'Optimal Total': folder_optimal_total
        })
        
        print(f"\n  {'='*76}")
        print(f"  {folder_name} Optimal Total ({experiments_processed} experiments): {folder_optimal_total:,} cycles")

# Create DataFrames
all_configs_df = pd.DataFrame(all_folder_results)
optimization_df = pd.DataFrame(optimization_summary)
folders_summary_df = pd.DataFrame(numbered_folder_summaries)

print("\n" + "="*80)
print("Numbered Folder Summaries")
print("="*80)
print(folders_summary_df.to_string(index=False))

print("\n" + "="*80)
print(f"GRAND TOTAL (All Optimal Configurations): {folders_summary_df['Optimal Total'].sum():,} cycles")
print("="*80)

# Display folder summaries
folders_summary_df
# Out:
# ================================================================================
# INCREMENTAL OPTIMIZATION Analysis - Decoder-BS16
# Finding optimal number of experts to move from PIM to NPU
# ================================================================================
#
#
# ================================================================================
# Processing: 1st/
# ================================================================================
#
#   Exp 2 (layer2.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 411,532
#     Minimum Total (MAX): 411,532 cycles
#   Exp 3 (layer3.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 392,368
#     Minimum Total (MAX): 392,368 cycles
#   Exp 4 (layer4.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 403,948
#     Minimum Total (MAX): 403,948 cycles
#   Exp 5 (layer5.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,890 | PIM Time: 434,376
#     Minimum Total (MAX): 434,376 cycles
#   Exp 6 (layer6.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 409,621
#     Minimum Total (MAX): 409,621 cycles
#   Exp 7 (layer7.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,891 | PIM Time: 415,637
#     Minimum Total (MAX): 415,637 cycles
#   Exp 8 (layer8.txt, 56 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,891 | PIM Time: 385,746
#     Minimum Total (MAX): 385,746 cycles
#   Exp 9 (layer9.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 415,674
#     Minimum Total (MAX): 415,674 cycles
#
#   ============================================================================
#   1st Optimal Total (8 experiments): 3,268,902 cycles
#
# ================================================================================
# Processing: 2nd/
# ================================================================================
#
#   Exp 2 (layer2.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 410,081
#     Minimum Total (MAX): 410,081 cycles
#   Exp 3 (layer3.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 409,508
#     Minimum Total (MAX): 409,508 cycles
#   Exp 4 (layer4.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 420,708
#     Minimum Total (MAX): 420,708 cycles
#   Exp 5 (layer5.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,890 | PIM Time: 402,841
#     Minimum Total (MAX): 402,841 cycles
#   Exp 6 (layer6.txt, 56 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 431,133
#     Minimum Total (MAX): 431,133 cycles
#   Exp 7 (layer7.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 403,945
#     Minimum Total (MAX): 403,945 cycles
#   Exp 8 (layer8.txt, 55 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,893 | PIM Time: 397,678
#     Minimum Total (MAX): 397,678 cycles
#   Exp 9 (layer9.txt, 56 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,955 | PIM Time: 403,310
#     Minimum Total (MAX): 403,310 cycles
#
#   ============================================================================
#   2nd Optimal Total (8 experiments): 3,279,204 cycles
#
# ================================================================================
# Processing: 3rd/
# ================================================================================
#
#   Exp 2 (layer2.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 421,420
#     Minimum Total (MAX): 421,420 cycles
#   Exp 3 (layer3.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 415,784
#     Minimum Total (MAX): 415,784 cycles
#   Exp 4 (layer4.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,893 | PIM Time: 382,116
#     Minimum Total (MAX): 382,116 cycles
#   Exp 5 (layer5.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,890 | PIM Time: 403,992
#     Minimum Total (MAX): 403,992 cycles
#   Exp 6 (layer6.txt, 54 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 394,031
#     Minimum Total (MAX): 394,031 cycles
#   Exp 7 (layer7.txt, 55 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 415,817
#     Minimum Total (MAX): 415,817 cycles
#   Exp 8 (layer8.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,893 | PIM Time: 424,349
#     Minimum Total (MAX): 424,349 cycles
#   Exp 9 (layer9.txt, 56 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 427,115
#     Minimum Total (MAX): 427,115 cycles
#
#   ============================================================================
#   3rd Optimal Total (8 experiments): 3,284,624 cycles
#
# ================================================================================
# Processing: 4th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 423,485
#     Minimum Total (MAX): 423,485 cycles
#   Exp 3 (layer3.txt, 64 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,786 | PIM Time: 432,901
#     Minimum Total (MAX): 432,901 cycles
#   Exp 4 (layer4.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,955 | PIM Time: 406,149
#     Minimum Total (MAX): 406,149 cycles
#   Exp 5 (layer5.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 404,274
#     Minimum Total (MAX): 404,274 cycles
#   Exp 6 (layer6.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,785 | PIM Time: 423,230
#     Minimum Total (MAX): 423,230 cycles
#   Exp 7 (layer7.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 417,446
#     Minimum Total (MAX): 417,446 cycles
#   Exp 8 (layer8.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 408,954
#     Minimum Total (MAX): 408,954 cycles
#   Exp 9 (layer9.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,890 | PIM Time: 438,182
#     Minimum Total (MAX): 438,182 cycles
#
#   ============================================================================
#   4th Optimal Total (8 experiments): 3,354,621 cycles
#
# ================================================================================
# Processing: 5th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 405,859
#     Minimum Total (MAX): 405,859 cycles
#   Exp 3 (layer3.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,786 | PIM Time: 398,807
#     Minimum Total (MAX): 398,807 cycles
#   Exp 4 (layer4.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 425,348
#     Minimum Total (MAX): 425,348 cycles
#   Exp 5 (layer5.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 406,425
#     Minimum Total (MAX): 406,425 cycles
#   Exp 6 (layer6.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,786 | PIM Time: 417,284
#     Minimum Total (MAX): 417,284 cycles
#   Exp 7 (layer7.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 405,856
#     Minimum Total (MAX): 405,856 cycles
#   Exp 8 (layer8.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,851 | PIM Time: 389,988
#     Minimum Total (MAX): 389,988 cycles
#   Exp 9 (layer9.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,851 | PIM Time: 411,516
#     Minimum Total (MAX): 411,516 cycles
#
#   ============================================================================
#   5th Optimal Total (8 experiments): 3,261,083 cycles
#
# ================================================================================
# Processing: 6th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 407,580
#     Minimum Total (MAX): 407,580 cycles
#   Exp 3 (layer3.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,786 | PIM Time: 404,647
#     Minimum Total (MAX): 404,647 cycles
#   Exp 4 (layer4.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 392,056
#     Minimum Total (MAX): 392,056 cycles
#   Exp 5 (layer5.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 417,318
#     Minimum Total (MAX): 417,318 cycles
#   Exp 6 (layer6.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 411,608
#     Minimum Total (MAX): 411,608 cycles
#   Exp 7 (layer7.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 397,719
#     Minimum Total (MAX): 397,719 cycles
#   Exp 8 (layer8.txt, 55 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,890 | PIM Time: 403,319
#     Minimum Total (MAX): 403,319 cycles
#   Exp 9 (layer9.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 434,900
#     Minimum Total (MAX): 434,900 cycles
#
#   ============================================================================
#   6th Optimal Total (8 experiments): 3,269,147 cycles
#
# ================================================================================
# Processing: 7th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,852 | PIM Time: 386,105
#     Minimum Total (MAX): 386,105 cycles
#   Exp 3 (layer3.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,851 | PIM Time: 409,463
#     Minimum Total (MAX): 409,463 cycles
#   Exp 4 (layer4.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 393,769
#     Minimum Total (MAX): 393,769 cycles
#   Exp 5 (layer5.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,851 | PIM Time: 439,043
#     Minimum Total (MAX): 439,043 cycles
#   Exp 6 (layer6.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 405,572
#     Minimum Total (MAX): 405,572 cycles
#   Exp 7 (layer7.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 411,475
#     Minimum Total (MAX): 411,475 cycles
#   Exp 8 (layer8.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 415,417
#     Minimum Total (MAX): 415,417 cycles
#   Exp 9 (layer9.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,954 | PIM Time: 414,042
#     Minimum Total (MAX): 414,042 cycles
#
#   ============================================================================
#   7th Optimal Total (8 experiments): 3,274,886 cycles
#
# ================================================================================
# Processing: 8th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 440,699
#     Minimum Total (MAX): 440,699 cycles
#   Exp 3 (layer3.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 427,198
#     Minimum Total (MAX): 427,198 cycles
#   Exp 4 (layer4.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 410,055
#     Minimum Total (MAX): 410,055 cycles
#   Exp 5 (layer5.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,786 | PIM Time: 415,541
#     Minimum Total (MAX): 415,541 cycles
#   Exp 6 (layer6.txt, 63 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 433,120
#     Minimum Total (MAX): 433,120 cycles
#   Exp 7 (layer7.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 417,845
#     Minimum Total (MAX): 417,845 cycles
#   Exp 8 (layer8.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 403,312
#     Minimum Total (MAX): 403,312 cycles
#   Exp 9 (layer9.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 426,435
#     Minimum Total (MAX): 426,435 cycles
#
#   ============================================================================
#   8th Optimal Total (8 experiments): 3,374,205 cycles
#
# ================================================================================
# Processing: 9th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 423,258
#     Minimum Total (MAX): 423,258 cycles
#   Exp 3 (layer3.txt, 64 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,891 | PIM Time: 426,686
#     Minimum Total (MAX): 426,686 cycles
#   Exp 4 (layer4.txt, 63 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 410,756
#     Minimum Total (MAX): 410,756 cycles
#   Exp 5 (layer5.txt, 62 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 421,460
#     Minimum Total (MAX): 421,460 cycles
#   Exp 6 (layer6.txt, 63 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,851 | PIM Time: 415,486
#     Minimum Total (MAX): 415,486 cycles
#   Exp 7 (layer7.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 417,327
#     Minimum Total (MAX): 417,327 cycles
#   Exp 8 (layer8.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,787 | PIM Time: 409,395
#     Minimum Total (MAX): 409,395 cycles
#   Exp 9 (layer9.txt, 63 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 432,884
#     Minimum Total (MAX): 432,884 cycles
#
#   ============================================================================
#   9th Optimal Total (8 experiments): 3,357,252 cycles
#
# ================================================================================
# Processing: 10th/
# ================================================================================
#
#   Exp 2 (layer2.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,890 | PIM Time: 402,268
#     Minimum Total (MAX): 402,268 cycles
#   Exp 3 (layer3.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,852 | PIM Time: 403,837
#     Minimum Total (MAX): 403,837 cycles
#   Exp 4 (layer4.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 423,498
#     Minimum Total (MAX): 423,498 cycles
#   Exp 5 (layer5.txt, 59 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,892 | PIM Time: 392,413
#     Minimum Total (MAX): 392,413 cycles
#   Exp 6 (layer6.txt, 61 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,954 | PIM Time: 419,249
#     Minimum Total (MAX): 419,249 cycles
#   Exp 7 (layer7.txt, 58 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,788 | PIM Time: 408,751
#     Minimum Total (MAX): 408,751 cycles
#   Exp 8 (layer8.txt, 57 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,994 | PIM Time: 392,789
#     Minimum Total (MAX): 392,789 cycles
#   Exp 9 (layer9.txt, 60 active experts):
#     Optimal: 1 experts on NPU
#     NPU Time: 353,889 | PIM Time: 404,329
#     Minimum Total (MAX): 404,329 cycles
#
#   ============================================================================
#   10th Optimal Total (8 experiments): 3,247,134 cycles
#
# ================================================================================
# Numbered Folder Summaries
# ================================================================================
# Numbered Folder  Experiments Processed  Optimal Total
#             1st                      8        3268902
#             2nd                      8        3279204
#             3rd                      8        3284624
#             4th                      8        3354621
#             5th                      8        3261083
#             6th                      8        3269147
#             7th                      8        3274886
#             8th                      8        3374205
#             9th                      8        3357252
#            10th                      8        3247134
#
# ================================================================================
# GRAND TOTAL (All Optimal Configurations): 32,971,058 cycles
# ================================================================================
#   Numbered Folder  Experiments Processed  Optimal Total
# 0             1st                      8        3268902
# 1             2nd                      8        3279204
# 2             3rd                      8        3284624
# 3             4th                      8        3354621
# 4             5th                      8        3261083
# 5             6th                      8        3269147
# 6             7th                      8        3274886
# 7             8th                      8        3374205
# 8             9th                      8        3357252
# 9            10th                      8        3247134

# %%
import pandas as pd
import os
import re
from collections import defaultdict

# Base directory
base_dir = 'Decoder-BS32-deep'

print("="*80)
print("INCREMENTAL OPTIMIZATION Analysis - REUSE AWARE (LFU Cache)")
print("Finding optimal number of experts to move from PIM to NPU")
print("Cache: 16 experts per layer (25%), LFU eviction policy")
print("="*80)
print()

# Numbered folders to process
numbered_folders = ['1st', '2nd', '3rd', '4th', '5th', '6th', '7th', '8th', '9th', '10th']

# Cache management (persistent across iterations)
# layer_cache[exp_num] = set of cached expert numbers (max 16 per layer)
# layer_freq[exp_num][expert_num] = usage frequency
layer_cache = defaultdict(set)
layer_freq = defaultdict(lambda: defaultdict(int))
CACHE_SIZE = 10  # 25% of 64 experts

# Store results
all_folder_results = []
optimization_summary = []
numbered_folder_summaries = []

# Process each numbered folder (these are ITERATIONS executed sequentially)
for folder_name in numbered_folders:
    folder_path = os.path.join(base_dir, folder_name)
    
    if not os.path.exists(folder_path):
        print(f"⚠ {folder_name}/ not found, skipping...")
        continue
    
    print(f"\n{'='*80}")
    print(f"Processing: {folder_name}/")
    print('='*80)
    print()
    
    folder_optimal_total = 0
    experiments_processed = 0
    
    # Process experiment folders 2-26
    for exp_num in range(2, 13):
        # Determine which layer file to use (cycling through 2-9)
        layer_num = ((exp_num - 2) % 8) + 2
        layer_file = os.path.join(folder_path, f'layer{layer_num}.txt')
        
        npu_txt = os.path.join(folder_path, 'npu', str(exp_num), 'SA_stage_E.txt')
        pim_txt = os.path.join(folder_path, 'pim', str(exp_num), 'SA_stage_E.txt')
        
        # Check if files exist
        if not os.path.exists(layer_file):
            continue
        if not os.path.exists(npu_txt):
            continue
        if not os.path.exists(pim_txt):
            continue
        
        # Read layer file to get ordered list of experts (top to bottom by usage)
        with open(layer_file, 'r') as f:
            layer_content = f.read()
        
        expert_order = []
        for line in layer_content.split('\n'):
            match = re.search(r'Expert\s+(\d+)\s+(\d+)', line)
            if match:
                expert_num = int(match.group(1))
                token_count = int(match.group(2))
                # Only include active experts (token_count > 0)
                if token_count > 0:
                    expert_order.append(expert_num)
        
        total_active_experts = len(expert_order)
        
        if total_active_experts == 0:
            continue
        
        # Read NPU data
        with open(npu_txt, 'r') as f:
            npu_content = f.read()
        
        npu_data = {}
        for line in npu_content.split('\n'):
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'NPU Expert' in line or 'Decoder' in line:
                continue
            
            parts = line.split()
            if len(parts) >= 6:
                try:
                    expert_num = int(parts[0])
                    param_load = int(parts[1])
                    total_compute = int(parts[5])
                    npu_data[expert_num] = {'param_load': param_load, 'total_compute': total_compute}
                except (ValueError, IndexError):
                    continue
        
        # Read PIM data
        with open(pim_txt, 'r') as f:
            pim_content = f.read()
        
        # Extract activation movements
        activation_1 = 0
        activation_2 = 0
        
        for line in pim_content.split('\n'):
            if 'activation_movement_1' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_1 = int(float(match.group(1)))
            elif 'activation_movement_2' in line and 'cycles' in line:
                match = re.search(r'([\d.]+)\s+cycles', line)
                if match:
                    activation_2 = int(float(match.group(1)))
        
        pim_data = {}
        for line in pim_content.split('\n'):
            if not line.strip() or '=' in line or 'Expert Number' in line or 'Expert Operations' in line or 'Note:' in line or 'Activation' in line or '-' in line[:3] or 'PIM Expert' in line or 'Decoder' in line or 'BS' in line:
                continue
            
            parts = line.split()
            if len(parts) >= 5:
                try:
                    expert_num = int(parts[0])
                    total_compute = int(parts[4])
                    pim_data[expert_num] = {'total_compute': total_compute}
                except (ValueError, IndexError):
                    continue
        
        # CACHE-AWARE BENEFIT CALCULATION
        # Calculate benefit score for each active expert
        # Benefit = PIM_time - (NPU_time + param_load_cost)
        # Higher benefit = more worth moving to NPU
        expert_benefits = []
        
        for exp in expert_order:
            if exp in npu_data and exp in pim_data:
                pim_time = pim_data[exp]['total_compute']
                npu_compute = npu_data[exp]['total_compute']
                
                # Cache-aware param_load cost (use exp_num as cache key, not layer_num)
                if exp in layer_cache[exp_num]:
                    param_load_cost = 0  # Cached → zero cost ✅
                else:
                    param_load_cost = npu_data[exp]['param_load']
                
                npu_time = npu_compute + param_load_cost
                benefit = pim_time - npu_time
                
                expert_benefits.append({
                    'expert': exp,
                    'benefit': benefit,
                    'cached': exp in layer_cache[exp_num]
                })
        
        # Sort experts by benefit (descending - highest benefit first)
        # This is the DynaNDE algorithm: prioritize experts with highest benefit
        expert_benefits.sort(key=lambda x: x['benefit'], reverse=True)
        benefit_sorted_experts = [e['expert'] for e in expert_benefits]
        
        # Store top 5 benefits for debugging/display
        top_5_benefits = expert_benefits[:5] if len(expert_benefits) >= 5 else expert_benefits
        
        # Now test configurations from 0 to total_active_experts
        # Using BENEFIT-SORTED ORDER (not layer.txt order)
        # Cached experts naturally rank higher due to zero param_load cost
        configurations = []
        
        for num_on_npu in range(0, total_active_experts + 1):
            if num_on_npu == 0:
                # All on PIM
                npu_time = 0
                pim_compute = sum(pim_data[exp]['total_compute'] for exp in benefit_sorted_experts if exp in pim_data)
                pim_time = pim_compute + activation_1 + activation_2
                total_cycles = pim_time
            else:
                # Top num_on_npu experts on NPU (by BENEFIT, not layer.txt order)
                top_experts = benefit_sorted_experts[:num_on_npu]
                remaining_experts = benefit_sorted_experts[num_on_npu:]
                
                # NPU PARALLEL EXECUTION MODEL:
                # - Param loading (non-cached) and compute (cached) happen in PARALLEL
                # - Last expert compute happens after (sequential)
                
                total_param_load = 0
                sum_cached_compute = 0
                
                for exp in top_experts:
                    if exp in npu_data:
                        if exp not in layer_cache[exp_num]:
                            # Non-cached: add param_load
                            total_param_load += npu_data[exp]['param_load']
                        else:
                            # Cached: add compute (happens during param loading phase)
                            sum_cached_compute += npu_data[exp]['total_compute']
                
                # Last expert compute (always sequential at the end)
                last_expert_compute = npu_data[top_experts[-1]]['total_compute'] if top_experts[-1] in npu_data else 0
                
                # If last expert is cached, subtract it from sum_cached_compute to avoid double counting
                if top_experts[-1] in layer_cache[exp_num]:
                    sum_cached_compute -= last_expert_compute
                
                # Calculate NPU time based on execution model
                if total_param_load == 0:
                    # ALL cached: no loading, all compute sequentially
                    npu_time = sum(npu_data[exp]['total_compute'] for exp in top_experts if exp in npu_data)
                else:
                    # Mixed: param loading and cached compute in parallel, then last compute
                    phase1 = max(total_param_load, sum_cached_compute)
                    npu_time = phase1 + last_expert_compute
                
                # PIM: total compute of remaining experts
                pim_compute = sum(pim_data[exp]['total_compute'] for exp in remaining_experts if exp in pim_data)
                
                if num_on_npu == total_active_experts:
                    # All on NPU, no PIM usage
                    pim_time = 0
                else:
                    # PIM is active
                    pim_time = pim_compute + activation_1 + activation_2
                
                # Total = MAX because NPU and PIM run simultaneously (PARALLEL)
                total_cycles = max(npu_time, pim_time)
            
            configurations.append({
                'Numbered Folder': folder_name,
                'Experiment': exp_num,
                'Experts on NPU': num_on_npu,
                'NPU Time': npu_time,
                'PIM Time': pim_time,
                'Total Cycles': total_cycles
            })
        
        # Find optimal configuration (minimum total cycles)
        min_config = min(configurations, key=lambda x: x['Total Cycles'])
        
        # UPDATE CACHE: Add optimal NPU experts to cache and update frequencies
        optimal_npu_count = min_config['Experts on NPU']
        if optimal_npu_count > 0:
            # Use BENEFIT-SORTED order (not layer.txt order)
            optimal_npu_experts = benefit_sorted_experts[:optimal_npu_count]
            
            # Track which experts are newly added vs already cached
            newly_cached = []
            already_cached = []
            
            for exp in optimal_npu_experts:
                # Increment usage frequency (use exp_num as key)
                layer_freq[exp_num][exp] += 1
                
                # Add to cache if not already there
                if exp not in layer_cache[exp_num]:
                    layer_cache[exp_num].add(exp)
                    newly_cached.append(exp)
                else:
                    already_cached.append(exp)
            
            # LFU EVICTION: If cache exceeds 16, evict least frequently used
            if len(layer_cache[exp_num]) > CACHE_SIZE:
                # Get all cached experts with their frequencies
                cached_experts_freq = [(exp, layer_freq[exp_num][exp]) for exp in layer_cache[exp_num]]
                # Sort by frequency (ascending) - least frequent first
                cached_experts_freq.sort(key=lambda x: x[1])
                
                # Evict until cache size = 16
                num_to_evict = len(layer_cache[exp_num]) - CACHE_SIZE
                evicted = []
                for i in range(num_to_evict):
                    exp_to_evict = cached_experts_freq[i][0]
                    layer_cache[exp_num].remove(exp_to_evict)
                    evicted.append(exp_to_evict)
                
                cache_status = f"Cache FULL → Evicted {num_to_evict} LFU: {evicted}"
            else:
                cache_status = f"Cache: {len(layer_cache[exp_num])}/{CACHE_SIZE}"
        else:
            # No NPU experts in optimal config
            newly_cached = []
            already_cached = []
            cache_status = f"Cache: {len(layer_cache[exp_num])}/{CACHE_SIZE} (no NPU experts)"
        
        print(f"  Exp {exp_num} (uses layer{layer_num}.txt, {total_active_experts} active experts):")
        print(f"    [Layer {exp_num} has unique 64 experts, cache key = {exp_num}]")
        
        # Show top 5 experts by benefit (for verification)
        top_5_str = ", ".join([f"E{e['expert']}({'C' if e['cached'] else 'M'}:{e['benefit']:+,})" for e in top_5_benefits])
        print(f"    Top 5 by benefit: {top_5_str}")
        
        print(f"    Optimal: {min_config['Experts on NPU']} experts on NPU")
        if optimal_npu_count > 0:
            # Show which experts were selected (benefit-based order)
            cached_in_optimal = [e for e in optimal_npu_experts if e in already_cached]
            print(f"    Selected experts (by benefit): {optimal_npu_experts}")
            print(f"    Cache hits: {len(already_cached)} (experts: {cached_in_optimal})")
            print(f"    Cache misses: {len(newly_cached)} (experts: {newly_cached})")
        print(f"    NPU Time: {min_config['NPU Time']:,} | PIM Time: {min_config['PIM Time']:,}")
        print(f"    Minimum Total (MAX): {min_config['Total Cycles']:,} cycles")
        print(f"    {cache_status}")
        
        # Store all configurations for this experiment
        all_folder_results.extend(configurations)
        
        # Store optimization summary for this experiment
        optimization_summary.append({
            'Numbered Folder': folder_name,
            'Experiment': exp_num,
            'Layer File': f'layer{layer_num}.txt',
            'Total Active Experts': total_active_experts,
            'Optimal Experts on NPU': min_config['Experts on NPU'],
            'Cache Hits': len(already_cached),
            'Cache Misses': len(newly_cached),
            'Cache Size': len(layer_cache[exp_num]),
            'NPU Time': min_config['NPU Time'],
            'PIM Time': min_config['PIM Time'],
            'Optimal Total Cycles': min_config['Total Cycles']
        })
        
        folder_optimal_total += min_config['Total Cycles']
        experiments_processed += 1
    
    # Store numbered folder summary
    if experiments_processed > 0:
        numbered_folder_summaries.append({
            'Numbered Folder': folder_name,
            'Experiments Processed': experiments_processed,
            'Optimal Total': folder_optimal_total
        })
        
        print(f"\n  {'='*76}")
        print(f"  {folder_name} Optimal Total ({experiments_processed} experiments): {folder_optimal_total:,} cycles")

# Create DataFrames
all_configs_df = pd.DataFrame(all_folder_results)
optimization_df = pd.DataFrame(optimization_summary)
folders_summary_df = pd.DataFrame(numbered_folder_summaries)

print("\n" + "="*80)
print("Numbered Folder Summaries")
print("="*80)
print(folders_summary_df.to_string(index=False))

print("\n" + "="*80)
print(f"GRAND TOTAL (All Optimal Configurations): {folders_summary_df['Optimal Total'].sum():,} cycles")
print("="*80)

# Cache Statistics Summary
print("\n" + "="*80)
print("Cache Statistics After All Iterations")
print("="*80)
cache_stats = []
for exp_num in sorted(layer_cache.keys()):
    total_uses = sum(layer_freq[exp_num].values())
    avg_freq = total_uses / len(layer_cache[exp_num]) if layer_cache[exp_num] else 0
    # Determine which layer.txt file this experiment uses
    display_layer_num = ((exp_num - 2) % 8) + 2
    cache_stats.append({
        'Exp (Layer)': f'Exp {exp_num} (layer{display_layer_num}.txt)',
        'Cached Experts': len(layer_cache[exp_num]),
        'Total Uses': total_uses,
        'Avg Frequency': f'{avg_freq:.1f}'
    })

cache_stats_df = pd.DataFrame(cache_stats)
print(cache_stats_df.to_string(index=False))

print("\n" + "="*80)
total_cache_hits = optimization_df['Cache Hits'].sum()
total_cache_misses = optimization_df['Cache Misses'].sum()
hit_rate = (total_cache_hits / (total_cache_hits + total_cache_misses) * 100) if (total_cache_hits + total_cache_misses) > 0 else 0
print(f"Total Cache Hits: {total_cache_hits} | Total Cache Misses: {total_cache_misses}")
print(f"Cache Hit Rate: {hit_rate:.2f}%")
print("="*80)

# Final Summary
print("\n" + "="*80)
print("FINAL SUMMARY - REUSE AWARE OPTIMIZATION")
print("="*80)
grand_total_reuse = folders_summary_df['Optimal Total'].sum()
print(f"GRAND TOTAL (All Iterations with Cache): {grand_total_reuse:,} cycles")
print(f"Total Experiments Processed: {optimization_df.shape[0]}")
print(f"Cache Hit Rate: {hit_rate:.2f}%")
print("="*80)

# Display folder summaries
folders_summary_df
# Out:
# ================================================================================
# INCREMENTAL OPTIMIZATION Analysis - REUSE AWARE (LFU Cache)
# Finding optimal number of experts to move from PIM to NPU
# Cache: 16 experts per layer (25%), LFU eviction policy
# ================================================================================
#
#
# ================================================================================
# Processing: 1st/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 61 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E21(M:-1,368,762), E63(M:-1,369,282), E54(M:-1,369,326), E19(M:-1,369,346), E12(M:-1,369,347)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [21]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [21])
#     NPU Time: 1,415,092 | PIM Time: 1,624,043
#     Minimum Total (MAX): 1,624,043 cycles
#     Cache: 1/10
#   Exp 3 (uses layer3.txt, 60 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E26(M:-1,368,834), E48(M:-1,368,950), E6(M:-1,368,998), E4(M:-1,369,557), E15(M:-1,369,654)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [26]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [26])
#     NPU Time: 1,415,092 | PIM Time: 1,551,359
#     Minimum Total (MAX): 1,551,359 cycles
#     Cache: 1/10
#   Exp 4 (uses layer4.txt, 60 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E63(M:-1,347,530), E7(M:-1,368,750), E50(M:-1,368,950), E44(M:-1,369,010), E46(M:-1,369,425)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [63]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [63])
#     NPU Time: 1,415,508 | PIM Time: 1,596,918
#     Minimum Total (MAX): 1,596,918 cycles
#     Cache: 1/10
#   Exp 5 (uses layer5.txt, 62 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E14(M:-1,347,530), E57(M:-1,368,830), E55(M:-1,369,326), E3(M:-1,369,342), E29(M:-1,369,342)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [14]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [14])
#     NPU Time: 1,415,500 | PIM Time: 1,715,933
#     Minimum Total (MAX): 1,715,933 cycles
#     Cache: 1/10
#   Exp 6 (uses layer6.txt, 59 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E44(M:-1,368,846), E9(M:-1,368,942), E27(M:-1,369,058), E22(M:-1,369,262), E41(M:-1,369,342)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [44]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [44])
#     NPU Time: 1,415,093 | PIM Time: 1,619,493
#     Minimum Total (MAX): 1,619,493 cycles
#     Cache: 1/10
#   Exp 7 (uses layer7.txt, 58 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E28(M:-1,346,750), E6(M:-1,368,946), E10(M:-1,369,022), E50(M:-1,369,290), E57(M:-1,369,348)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [28]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [28])
#     NPU Time: 1,415,504 | PIM Time: 1,643,530
#     Minimum Total (MAX): 1,643,530 cycles
#     Cache: 1/10
#   Exp 8 (uses layer8.txt, 56 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E28(M:-1,347,530), E56(M:-1,368,738), E51(M:-1,368,894), E7(M:-1,368,918), E47(M:-1,369,342)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [28]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [28])
#     NPU Time: 1,415,501 | PIM Time: 1,524,908
#     Minimum Total (MAX): 1,524,908 cycles
#     Cache: 1/10
#   Exp 9 (uses layer9.txt, 58 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E23(M:-1,368,946), E3(M:-1,369,126), E42(M:-1,369,290), E61(M:-1,369,339), E47(M:-1,369,394)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [23]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [23])
#     NPU Time: 1,415,093 | PIM Time: 1,642,173
#     Minimum Total (MAX): 1,642,173 cycles
#     Cache: 1/10
#   Exp 10 (uses layer2.txt, 61 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E21(M:-1,368,762), E63(M:-1,369,282), E54(M:-1,369,326), E19(M:-1,369,346), E12(M:-1,369,347)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [21]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [21])
#     NPU Time: 1,415,092 | PIM Time: 1,624,043
#     Minimum Total (MAX): 1,624,043 cycles
#     Cache: 1/10
#   Exp 11 (uses layer3.txt, 60 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E26(M:-1,368,834), E48(M:-1,368,950), E6(M:-1,368,998), E4(M:-1,369,557), E15(M:-1,369,654)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [26]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [26])
#     NPU Time: 1,415,092 | PIM Time: 1,551,359
#     Minimum Total (MAX): 1,551,359 cycles
#     Cache: 1/10
#   Exp 12 (uses layer4.txt, 60 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E63(M:-1,347,530), E7(M:-1,368,750), E50(M:-1,368,950), E44(M:-1,369,010), E46(M:-1,369,425)
#     Optimal: 1 experts on NPU
#     Selected experts (by benefit): [63]
#     Cache hits: 0 (experts: [])
#     Cache misses: 1 (experts: [63])
#     NPU Time: 1,415,508 | PIM Time: 1,596,918
#     Minimum Total (MAX): 1,596,918 cycles
#     Cache: 1/10
#
#   ============================================================================
#   1st Optimal Total (11 experiments): 17,690,677 cycles
#
# ================================================================================
# Processing: 2nd/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 61 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E21(C:+22,410), E53(M:-1,368,938), E8(M:-1,369,258), E45(M:-1,369,399), E17(M:-1,369,598)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [21, 53]
#     Cache hits: 1 (experts: [21])
#     Cache misses: 1 (experts: [53])
#     NPU Time: 1,415,093 | PIM Time: 1,598,326
#     Minimum Total (MAX): 1,598,326 cycles
#     Cache: 2/10
#   Exp 3 (uses layer3.txt, 57 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E26(C:+22,569), E9(M:-1,368,366), E10(M:-1,368,614), E38(M:-1,368,754), E8(M:-1,369,146)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [26, 9]
#     Cache hits: 1 (experts: [26])
#     Cache misses: 1 (experts: [9])
#     NPU Time: 1,415,092 | PIM Time: 1,592,339
#     Minimum Total (MAX): 1,592,339 cycles
#     Cache: 2/10
#   Exp 4 (uses layer4.txt, 57 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E63(C:+22,410), E53(M:-1,368,606), E23(M:-1,368,666), E58(M:-1,368,890), E10(M:-1,368,938)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [63, 53]
#     Cache hits: 1 (experts: [63])
#     Cache misses: 1 (experts: [53])
#     NPU Time: 1,415,092 | PIM Time: 1,639,287
#     Minimum Total (MAX): 1,639,287 cycles
#     Cache: 2/10
#   Exp 5 (uses layer5.txt, 57 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E14(C:+22,358), E48(M:-1,346,558), E20(M:-1,347,530), E46(M:-1,368,498), E34(M:-1,368,922)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [14, 48]
#     Cache hits: 1 (experts: [14])
#     Cache misses: 1 (experts: [48])
#     NPU Time: 1,415,500 | PIM Time: 1,569,184
#     Minimum Total (MAX): 1,569,184 cycles
#     Cache: 2/10
#   Exp 6 (uses layer6.txt, 56 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E44(C:+23,256), E30(M:-1,346,826), E50(M:-1,368,338), E51(M:-1,368,578), E26(M:-1,368,598)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [44, 30]
#     Cache hits: 1 (experts: [44])
#     Cache misses: 1 (experts: [30])
#     NPU Time: 1,415,508 | PIM Time: 1,683,496
#     Minimum Total (MAX): 1,683,496 cycles
#     Cache: 2/10
#   Exp 7 (uses layer7.txt, 58 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E28(C:+44,554), E43(M:-1,346,794), E54(M:-1,368,598), E59(M:-1,368,638), E15(M:-1,368,862)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [28, 43]
#     Cache hits: 1 (experts: [28])
#     Cache misses: 1 (experts: [43])
#     NPU Time: 1,415,505 | PIM Time: 1,552,778
#     Minimum Total (MAX): 1,552,778 cycles
#     Cache: 2/10
#   Exp 8 (uses layer8.txt, 55 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E28(C:+22,414), E50(M:-1,347,522), E14(M:-1,368,758), E34(M:-1,368,894), E18(M:-1,369,022)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [28, 50]
#     Cache hits: 1 (experts: [28])
#     Cache misses: 1 (experts: [50])
#     NPU Time: 1,415,503 | PIM Time: 1,550,350
#     Minimum Total (MAX): 1,550,350 cycles
#     Cache: 2/10
#   Exp 9 (uses layer9.txt, 56 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E23(C:+22,406), E39(M:-1,346,542), E5(M:-1,368,754), E38(M:-1,368,890), E10(M:-1,368,926)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [23, 39]
#     Cache hits: 1 (experts: [23])
#     Cache misses: 1 (experts: [39])
#     NPU Time: 1,415,757 | PIM Time: 1,571,264
#     Minimum Total (MAX): 1,571,264 cycles
#     Cache: 2/10
#   Exp 10 (uses layer2.txt, 61 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E21(C:+22,410), E53(M:-1,368,938), E8(M:-1,369,258), E45(M:-1,369,399), E17(M:-1,369,598)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [21, 53]
#     Cache hits: 1 (experts: [21])
#     Cache misses: 1 (experts: [53])
#     NPU Time: 1,415,093 | PIM Time: 1,598,326
#     Minimum Total (MAX): 1,598,326 cycles
#     Cache: 2/10
#   Exp 11 (uses layer3.txt, 57 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E26(C:+22,569), E9(M:-1,368,366), E10(M:-1,368,614), E38(M:-1,368,754), E8(M:-1,369,146)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [26, 9]
#     Cache hits: 1 (experts: [26])
#     Cache misses: 1 (experts: [9])
#     NPU Time: 1,415,092 | PIM Time: 1,592,339
#     Minimum Total (MAX): 1,592,339 cycles
#     Cache: 2/10
#   Exp 12 (uses layer4.txt, 57 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E63(C:+22,410), E53(M:-1,368,606), E23(M:-1,368,666), E58(M:-1,368,890), E10(M:-1,368,938)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [63, 53]
#     Cache hits: 1 (experts: [63])
#     Cache misses: 1 (experts: [53])
#     NPU Time: 1,415,092 | PIM Time: 1,639,287
#     Minimum Total (MAX): 1,639,287 cycles
#     Cache: 2/10
#
#   ============================================================================
#   2nd Optimal Total (11 experiments): 17,586,976 cycles
#
# ================================================================================
# Processing: 3rd/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 61 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E21(C:+22,406), E53(C:+22,268), E36(M:-1,368,622), E7(M:-1,368,634), E17(M:-1,368,702)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [21, 53, 36]
#     Cache hits: 2 (experts: [21, 53])
#     Cache misses: 1 (experts: [36])
#     NPU Time: 1,415,088 | PIM Time: 1,619,564
#     Minimum Total (MAX): 1,619,564 cycles
#     Cache: 3/10
#   Exp 3 (uses layer3.txt, 59 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E9(C:+45,270), E38(M:-1,347,586), E50(M:-1,368,622), E33(M:-1,368,658), E55(M:-1,368,958)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [9, 38]
#     Cache hits: 1 (experts: [9])
#     Cache misses: 1 (experts: [38])
#     NPU Time: 1,415,502 | PIM Time: 1,598,021
#     Minimum Total (MAX): 1,598,021 cycles
#     Cache: 3/10
#   Exp 4 (uses layer4.txt, 57 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E53(C:+22,406), E63(C:+22,358), E33(M:-1,347,538), E58(M:-1,368,814), E10(M:-1,369,341)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [53, 63, 33]
#     Cache hits: 2 (experts: [53, 63])
#     Cache misses: 1 (experts: [33])
#     NPU Time: 1,415,509 | PIM Time: 1,462,226
#     Minimum Total (MAX): 1,462,226 cycles
#     Cache: 3/10
#   Exp 5 (uses layer5.txt, 60 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E48(C:+44,620), E14(C:+23,592), E25(M:-1,347,454), E37(M:-1,347,530), E12(M:-1,368,886)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [48, 14, 25]
#     Cache hits: 2 (experts: [48, 14])
#     Cache misses: 1 (experts: [25])
#     NPU Time: 1,415,500 | PIM Time: 1,528,947
#     Minimum Total (MAX): 1,528,947 cycles
#     Cache: 3/10
#   Exp 6 (uses layer6.txt, 54 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E30(C:+44,434), E44(C:+23,094), E58(M:-1,368,366), E17(M:-1,368,422), E57(M:-1,368,518)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [30, 44, 58]
#     Cache hits: 2 (experts: [30, 44])
#     Cache misses: 1 (experts: [58])
#     NPU Time: 1,415,092 | PIM Time: 1,486,863
#     Minimum Total (MAX): 1,486,863 cycles
#     Cache: 3/10
#   Exp 7 (uses layer7.txt, 55 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E28(C:+44,550), E58(M:-1,347,458), E34(M:-1,368,530), E50(M:-1,368,606), E45(M:-1,368,610)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [28, 58]
#     Cache hits: 1 (experts: [28])
#     Cache misses: 1 (experts: [58])
#     NPU Time: 1,415,502 | PIM Time: 1,598,737
#     Minimum Total (MAX): 1,598,737 cycles
#     Cache: 3/10
#   Exp 8 (uses layer8.txt, 57 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E28(C:+22,410), E50(C:+22,406), E34(M:-1,347,430), E15(M:-1,347,538), E57(M:-1,368,886)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [28, 50, 34]
#     Cache hits: 2 (experts: [28, 50])
#     Cache misses: 1 (experts: [34])
#     NPU Time: 1,415,503 | PIM Time: 1,634,569
#     Minimum Total (MAX): 1,634,569 cycles
#     Cache: 3/10
#   Exp 9 (uses layer9.txt, 56 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E39(C:+45,182), E23(C:+22,414), E50(M:-1,347,522), E15(M:-1,347,530), E8(M:-1,347,782)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [39, 23, 50]
#     Cache hits: 2 (experts: [39, 23])
#     Cache misses: 1 (experts: [50])
#     NPU Time: 1,415,500 | PIM Time: 1,620,943
#     Minimum Total (MAX): 1,620,943 cycles
#     Cache: 3/10
#   Exp 10 (uses layer2.txt, 61 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E21(C:+22,406), E53(C:+22,268), E36(M:-1,368,622), E7(M:-1,368,634), E17(M:-1,368,702)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [21, 53, 36]
#     Cache hits: 2 (experts: [21, 53])
#     Cache misses: 1 (experts: [36])
#     NPU Time: 1,415,088 | PIM Time: 1,619,564
#     Minimum Total (MAX): 1,619,564 cycles
#     Cache: 3/10
#   Exp 11 (uses layer3.txt, 59 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E9(C:+45,270), E38(M:-1,347,586), E50(M:-1,368,622), E33(M:-1,368,658), E55(M:-1,368,958)
#     Optimal: 2 experts on NPU
#     Selected experts (by benefit): [9, 38]
#     Cache hits: 1 (experts: [9])
#     Cache misses: 1 (experts: [38])
#     NPU Time: 1,415,502 | PIM Time: 1,598,021
#     Minimum Total (MAX): 1,598,021 cycles
#     Cache: 3/10
#   Exp 12 (uses layer4.txt, 57 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E53(C:+22,406), E63(C:+22,358), E33(M:-1,347,538), E58(M:-1,368,814), E10(M:-1,369,341)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [53, 63, 33]
#     Cache hits: 2 (experts: [53, 63])
#     Cache misses: 1 (experts: [33])
#     NPU Time: 1,415,509 | PIM Time: 1,462,226
#     Minimum Total (MAX): 1,462,226 cycles
#     Cache: 3/10
#
#   ============================================================================
#   3rd Optimal Total (11 experiments): 17,229,681 cycles
#
# ================================================================================
# Processing: 4th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 61 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E21(C:+45,242), E53(C:+44,743), E36(C:+22,410), E45(M:-1,368,694), E6(M:-1,369,258)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [21, 53, 36, 45]
#     Cache hits: 3 (experts: [21, 53, 36])
#     Cache misses: 1 (experts: [45])
#     NPU Time: 1,415,092 | PIM Time: 1,557,176
#     Minimum Total (MAX): 1,557,176 cycles
#     Cache: 4/10
#   Exp 3 (uses layer3.txt, 64 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E9(C:+23,212), E26(C:+22,418), E38(C:+22,410), E36(M:-1,368,366), E42(M:-1,368,714)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [9, 26, 38, 36]
#     Cache hits: 3 (experts: [9, 26, 38])
#     Cache misses: 1 (experts: [36])
#     NPU Time: 1,415,092 | PIM Time: 1,642,704
#     Minimum Total (MAX): 1,642,704 cycles
#     Cache: 4/10
#   Exp 4 (uses layer4.txt, 61 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E53(C:+44,801), E63(C:+23,196), E33(C:+23,052), E1(M:-1,347,778), E2(M:-1,368,398)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [53, 63, 33, 1]
#     Cache hits: 3 (experts: [53, 63, 33])
#     Cache misses: 1 (experts: [1])
#     NPU Time: 1,415,757 | PIM Time: 1,512,314
#     Minimum Total (MAX): 1,512,314 cycles
#     Cache: 4/10
#   Exp 5 (uses layer5.txt, 61 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E14(C:+44,854), E25(C:+22,612), E48(C:+22,340), E4(M:-1,368,566), E52(M:-1,368,934)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [14, 25, 48, 4]
#     Cache hits: 3 (experts: [14, 25, 48])
#     Cache misses: 1 (experts: [4])
#     NPU Time: 1,415,092 | PIM Time: 1,504,830
#     Minimum Total (MAX): 1,504,830 cycles
#     Cache: 4/10
#   Exp 6 (uses layer6.txt, 62 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E58(C:+23,112), E44(C:+22,448), E30(C:+22,350), E47(M:-1,368,742), E27(M:-1,368,782)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [58, 44, 30, 47]
#     Cache hits: 3 (experts: [58, 44, 30])
#     Cache misses: 1 (experts: [47])
#     NPU Time: 1,415,092 | PIM Time: 1,602,416
#     Minimum Total (MAX): 1,602,416 cycles
#     Cache: 4/10
#   Exp 7 (uses layer7.txt, 61 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E28(C:+45,342), E58(C:+23,052), E43(C:+22,410), E52(M:-1,368,538), E62(M:-1,368,834)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [28, 58, 43, 52]
#     Cache hits: 3 (experts: [28, 58, 43])
#     Cache misses: 1 (experts: [52])
#     NPU Time: 1,415,094 | PIM Time: 1,557,618
#     Minimum Total (MAX): 1,557,618 cycles
#     Cache: 4/10
#   Exp 8 (uses layer8.txt, 60 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E50(C:+22,348), E28(C:+22,344), E60(M:-1,368,894), E9(M:-1,368,934), E41(M:-1,369,006)
#     Optimal: 3 experts on NPU
#     Selected experts (by benefit): [50, 28, 60]
#     Cache hits: 2 (experts: [50, 28])
#     Cache misses: 1 (experts: [60])
#     NPU Time: 1,415,094 | PIM Time: 1,569,933
#     Minimum Total (MAX): 1,569,933 cycles
#     Cache: 4/10
#   Exp 9 (uses layer9.txt, 62 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E23(C:+22,574), E39(C:+22,366), E50(C:+22,344), E55(M:-1,346,634), E34(M:-1,368,834)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [23, 39, 50, 55]
#     Cache hits: 3 (experts: [23, 39, 50])
#     Cache misses: 1 (experts: [55])
#     NPU Time: 1,415,500 | PIM Time: 1,662,565
#     Minimum Total (MAX): 1,662,565 cycles
#     Cache: 4/10
#   Exp 10 (uses layer2.txt, 61 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E21(C:+45,242), E53(C:+44,743), E36(C:+22,410), E45(M:-1,368,694), E6(M:-1,369,258)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [21, 53, 36, 45]
#     Cache hits: 3 (experts: [21, 53, 36])
#     Cache misses: 1 (experts: [45])
#     NPU Time: 1,415,092 | PIM Time: 1,557,176
#     Minimum Total (MAX): 1,557,176 cycles
#     Cache: 4/10
#   Exp 11 (uses layer3.txt, 64 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E9(C:+23,212), E26(C:+22,418), E38(C:+22,410), E36(M:-1,368,366), E42(M:-1,368,714)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [9, 26, 38, 36]
#     Cache hits: 3 (experts: [9, 26, 38])
#     Cache misses: 1 (experts: [36])
#     NPU Time: 1,415,092 | PIM Time: 1,642,704
#     Minimum Total (MAX): 1,642,704 cycles
#     Cache: 4/10
#   Exp 12 (uses layer4.txt, 61 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E53(C:+44,801), E63(C:+23,196), E33(C:+23,052), E1(M:-1,347,778), E2(M:-1,368,398)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [53, 63, 33, 1]
#     Cache hits: 3 (experts: [53, 63, 33])
#     Cache misses: 1 (experts: [1])
#     NPU Time: 1,415,757 | PIM Time: 1,512,314
#     Minimum Total (MAX): 1,512,314 cycles
#     Cache: 4/10
#
#   ============================================================================
#   4th Optimal Total (11 experiments): 17,321,750 cycles
#
# ================================================================================
# Processing: 5th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 59 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E45(C:+44,862), E53(C:+23,056), E21(C:+22,354), E36(C:+22,276), E41(M:-1,368,342)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [45, 53, 21, 36, 41]
#     Cache hits: 4 (experts: [45, 53, 21, 36])
#     Cache misses: 1 (experts: [41])
#     NPU Time: 1,415,092 | PIM Time: 1,485,556
#     Minimum Total (MAX): 1,485,556 cycles
#     Cache: 5/10
#   Exp 3 (uses layer3.txt, 61 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E36(C:+44,546), E38(C:+22,406), E26(C:+22,370), E17(M:-1,368,342), E15(M:-1,368,526)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [36, 38, 26, 17]
#     Cache hits: 3 (experts: [36, 38, 26])
#     Cache misses: 1 (experts: [17])
#     NPU Time: 1,415,092 | PIM Time: 1,482,317
#     Minimum Total (MAX): 1,482,317 cycles
#     Cache: 5/10
#   Exp 4 (uses layer4.txt, 59 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E53(C:+44,546), E33(C:+44,438), E63(C:+22,414), E1(C:+22,340), E7(M:-1,368,570)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [53, 33, 63, 1, 7]
#     Cache hits: 4 (experts: [53, 33, 63, 1])
#     Cache misses: 1 (experts: [7])
#     NPU Time: 1,415,092 | PIM Time: 1,543,956
#     Minimum Total (MAX): 1,543,956 cycles
#     Cache: 5/10
#   Exp 5 (uses layer5.txt, 60 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E25(C:+44,740), E14(C:+23,028), E4(C:+22,916), E48(C:+22,370), E46(M:-1,368,342)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [25, 14, 4, 48, 46]
#     Cache hits: 4 (experts: [25, 14, 4, 48])
#     Cache misses: 1 (experts: [46])
#     NPU Time: 1,415,092 | PIM Time: 1,489,295
#     Minimum Total (MAX): 1,489,295 cycles
#     Cache: 5/10
#   Exp 6 (uses layer6.txt, 61 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E47(C:+44,854), E30(C:+44,550), E44(C:+23,112), E58(C:+23,040), E63(M:-1,368,678)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [47, 30, 44, 58, 63]
#     Cache hits: 4 (experts: [47, 30, 44, 58])
#     Cache misses: 1 (experts: [63])
#     NPU Time: 1,415,092 | PIM Time: 1,512,153
#     Minimum Total (MAX): 1,512,153 cycles
#     Cache: 5/10
#   Exp 7 (uses layer7.txt, 61 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E58(C:+23,580), E28(C:+23,192), E52(C:+22,370), E23(M:-1,368,742), E57(M:-1,368,890)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [58, 28, 52, 23]
#     Cache hits: 3 (experts: [58, 28, 52])
#     Cache misses: 1 (experts: [23])
#     NPU Time: 1,415,092 | PIM Time: 1,532,678
#     Minimum Total (MAX): 1,532,678 cycles
#     Cache: 5/10
#   Exp 8 (uses layer8.txt, 59 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E28(C:+23,044), E50(C:+23,036), E60(C:+22,880), E34(C:+22,422), E33(M:-1,368,614)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [28, 50, 60, 34, 33]
#     Cache hits: 4 (experts: [28, 50, 60, 34])
#     Cache misses: 1 (experts: [33])
#     NPU Time: 1,415,092 | PIM Time: 1,447,640
#     Minimum Total (MAX): 1,447,640 cycles
#     Cache: 5/10
#   Exp 9 (uses layer9.txt, 59 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E39(C:+44,438), E23(C:+23,101), E50(C:+22,410), E49(M:-1,368,546), E25(M:-1,368,622)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [39, 23, 50, 49]
#     Cache hits: 3 (experts: [39, 23, 50])
#     Cache misses: 1 (experts: [49])
#     NPU Time: 1,415,092 | PIM Time: 1,533,852
#     Minimum Total (MAX): 1,533,852 cycles
#     Cache: 5/10
#   Exp 10 (uses layer2.txt, 59 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E45(C:+44,862), E53(C:+23,056), E21(C:+22,354), E36(C:+22,276), E41(M:-1,368,342)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [45, 53, 21, 36, 41]
#     Cache hits: 4 (experts: [45, 53, 21, 36])
#     Cache misses: 1 (experts: [41])
#     NPU Time: 1,415,092 | PIM Time: 1,485,556
#     Minimum Total (MAX): 1,485,556 cycles
#     Cache: 5/10
#   Exp 11 (uses layer3.txt, 61 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E36(C:+44,546), E38(C:+22,406), E26(C:+22,370), E17(M:-1,368,342), E15(M:-1,368,526)
#     Optimal: 4 experts on NPU
#     Selected experts (by benefit): [36, 38, 26, 17]
#     Cache hits: 3 (experts: [36, 38, 26])
#     Cache misses: 1 (experts: [17])
#     NPU Time: 1,415,092 | PIM Time: 1,482,317
#     Minimum Total (MAX): 1,482,317 cycles
#     Cache: 5/10
#   Exp 12 (uses layer4.txt, 59 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E53(C:+44,546), E33(C:+44,438), E63(C:+22,414), E1(C:+22,340), E7(M:-1,368,570)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [53, 33, 63, 1, 7]
#     Cache hits: 4 (experts: [53, 33, 63, 1])
#     Cache misses: 1 (experts: [7])
#     NPU Time: 1,415,092 | PIM Time: 1,543,956
#     Minimum Total (MAX): 1,543,956 cycles
#     Cache: 5/10
#
#   ============================================================================
#   5th Optimal Total (11 experiments): 16,539,276 cycles
#
# ================================================================================
# Processing: 6th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 61 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E45(C:+45,746), E36(C:+44,739), E21(C:+23,244), E41(C:+22,988), E53(C:+22,828)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [45, 36, 21, 41, 53, 37]
#     Cache hits: 5 (experts: [45, 36, 21, 41, 53])
#     Cache misses: 1 (experts: [37])
#     NPU Time: 1,415,095 | PIM Time: 1,448,667
#     Minimum Total (MAX): 1,448,667 cycles
#     Cache: 6/10
#   Exp 3 (uses layer3.txt, 58 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E17(C:+23,044), E9(C:+22,414), E38(C:+22,405), E36(C:+22,336), E26(C:+22,336)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [17, 9, 38, 36, 26, 53]
#     Cache hits: 5 (experts: [17, 9, 38, 36, 26])
#     Cache misses: 1 (experts: [53])
#     NPU Time: 1,415,092 | PIM Time: 1,484,895
#     Minimum Total (MAX): 1,484,895 cycles
#     Cache: 6/10
#   Exp 4 (uses layer4.txt, 60 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E7(C:+44,749), E63(C:+23,596), E53(C:+22,418), E1(C:+22,406), E33(C:+22,354)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [7, 63, 53, 1, 33, 62]
#     Cache hits: 5 (experts: [7, 63, 53, 1, 33])
#     Cache misses: 1 (experts: [62])
#     NPU Time: 1,415,092 | PIM Time: 1,411,380
#     Minimum Total (MAX): 1,415,092 cycles
#     Cache: 6/10
#   Exp 5 (uses layer5.txt, 60 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E48(C:+45,750), E4(C:+22,418), E14(C:+22,414), E46(C:+22,370), E20(M:-1,368,346)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [48, 4, 14, 46, 20]
#     Cache hits: 4 (experts: [48, 4, 14, 46])
#     Cache misses: 1 (experts: [20])
#     NPU Time: 1,415,092 | PIM Time: 1,533,893
#     Minimum Total (MAX): 1,533,893 cycles
#     Cache: 6/10
#   Exp 6 (uses layer6.txt, 61 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E44(C:+45,194), E63(C:+23,124), E30(C:+22,414), E58(C:+22,414), E47(C:+22,350)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [44, 63, 30, 58, 47, 24]
#     Cache hits: 5 (experts: [44, 63, 30, 58, 47])
#     Cache misses: 1 (experts: [24])
#     NPU Time: 1,415,092 | PIM Time: 1,489,012
#     Minimum Total (MAX): 1,489,012 cycles
#     Cache: 6/10
#   Exp 7 (uses layer7.txt, 59 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E23(C:+44,438), E43(C:+22,569), E52(C:+22,358), E28(C:+22,358), E58(C:+22,344)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [23, 43, 52, 28, 58, 17]
#     Cache hits: 5 (experts: [23, 43, 52, 28, 58])
#     Cache misses: 1 (experts: [17])
#     NPU Time: 1,415,095 | PIM Time: 1,431,500
#     Minimum Total (MAX): 1,431,500 cycles
#     Cache: 6/10
#   Exp 8 (uses layer8.txt, 55 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E33(C:+44,494), E50(C:+23,200), E60(C:+22,616), E28(C:+22,414), E34(C:+22,336)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [33, 50, 60, 28, 34, 57]
#     Cache hits: 5 (experts: [33, 50, 60, 28, 34])
#     Cache misses: 1 (experts: [57])
#     NPU Time: 1,415,500 | PIM Time: 1,456,068
#     Minimum Total (MAX): 1,456,068 cycles
#     Cache: 6/10
#   Exp 9 (uses layer9.txt, 60 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E39(C:+45,306), E55(C:+23,572), E49(C:+23,212), E23(C:+23,048), E40(M:-1,368,342)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [39, 55, 49, 23, 40]
#     Cache hits: 4 (experts: [39, 55, 49, 23])
#     Cache misses: 1 (experts: [40])
#     NPU Time: 1,415,092 | PIM Time: 1,602,633
#     Minimum Total (MAX): 1,602,633 cycles
#     Cache: 6/10
#   Exp 10 (uses layer2.txt, 61 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E45(C:+45,746), E36(C:+44,739), E21(C:+23,244), E41(C:+22,988), E53(C:+22,828)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [45, 36, 21, 41, 53, 37]
#     Cache hits: 5 (experts: [45, 36, 21, 41, 53])
#     Cache misses: 1 (experts: [37])
#     NPU Time: 1,415,095 | PIM Time: 1,448,667
#     Minimum Total (MAX): 1,448,667 cycles
#     Cache: 6/10
#   Exp 11 (uses layer3.txt, 58 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E17(C:+23,044), E9(C:+22,414), E38(C:+22,405), E36(C:+22,336), E26(C:+22,336)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [17, 9, 38, 36, 26, 53]
#     Cache hits: 5 (experts: [17, 9, 38, 36, 26])
#     Cache misses: 1 (experts: [53])
#     NPU Time: 1,415,092 | PIM Time: 1,484,895
#     Minimum Total (MAX): 1,484,895 cycles
#     Cache: 6/10
#   Exp 12 (uses layer4.txt, 60 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E7(C:+44,749), E63(C:+23,596), E53(C:+22,418), E1(C:+22,406), E33(C:+22,354)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [7, 63, 53, 1, 33, 62]
#     Cache hits: 5 (experts: [7, 63, 53, 1, 33])
#     Cache misses: 1 (experts: [62])
#     NPU Time: 1,415,092 | PIM Time: 1,411,380
#     Minimum Total (MAX): 1,415,092 cycles
#     Cache: 6/10
#
#   ============================================================================
#   6th Optimal Total (11 experiments): 16,210,414 cycles
#
# ================================================================================
# Processing: 7th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 59 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E37(C:+45,182), E21(C:+44,490), E41(C:+22,414), E45(C:+22,406), E53(C:+22,354)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [37, 21, 41, 45, 53]
#     Cache hits: 5 (experts: [37, 21, 41, 45, 53])
#     Cache misses: 0 (experts: [])
#     NPU Time: 3,564 | PIM Time: 1,412,277
#     Minimum Total (MAX): 1,412,277 cycles
#     Cache: 6/10
#   Exp 3 (uses layer3.txt, 62 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E53(C:+22,414), E36(C:+22,410), E26(C:+22,406), E17(C:+22,354), E38(C:+22,346)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [53, 36, 26, 17, 38, 32]
#     Cache hits: 5 (experts: [53, 36, 26, 17, 38])
#     Cache misses: 1 (experts: [32])
#     NPU Time: 1,415,348 | PIM Time: 1,501,795
#     Minimum Total (MAX): 1,501,795 cycles
#     Cache: 7/10
#   Exp 4 (uses layer4.txt, 61 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E7(C:+22,960), E53(C:+22,952), E63(C:+22,414), E1(C:+22,410), E62(C:+22,354)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [7, 53, 63, 1, 62, 33, 50]
#     Cache hits: 6 (experts: [7, 53, 63, 1, 62, 33])
#     Cache misses: 1 (experts: [50])
#     NPU Time: 1,415,092 | PIM Time: 1,414,716
#     Minimum Total (MAX): 1,415,092 cycles
#     Cache: 7/10
#   Exp 5 (uses layer5.txt, 62 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E48(C:+44,546), E14(C:+23,196), E4(C:+22,497), E25(C:+22,414), E46(C:+22,414)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [48, 14, 4, 25, 46, 20, 42]
#     Cache hits: 6 (experts: [48, 14, 4, 25, 46, 20])
#     Cache misses: 1 (experts: [42])
#     NPU Time: 1,415,092 | PIM Time: 1,574,751
#     Minimum Total (MAX): 1,574,751 cycles
#     Cache: 7/10
#   Exp 6 (uses layer6.txt, 58 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E30(C:+45,398), E58(C:+22,992), E47(C:+22,571), E63(C:+22,414), E44(C:+22,362)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [30, 58, 47, 63, 44, 28]
#     Cache hits: 5 (experts: [30, 58, 47, 63, 44])
#     Cache misses: 1 (experts: [28])
#     NPU Time: 1,415,092 | PIM Time: 1,461,717
#     Minimum Total (MAX): 1,461,717 cycles
#     Cache: 7/10
#   Exp 7 (uses layer7.txt, 61 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E52(C:+44,490), E17(C:+23,016), E28(C:+22,410), E58(C:+22,406), E43(C:+22,370)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [52, 17, 28, 58, 43, 26]
#     Cache hits: 5 (experts: [52, 17, 28, 58, 43])
#     Cache misses: 1 (experts: [26])
#     NPU Time: 1,415,092 | PIM Time: 1,488,626
#     Minimum Total (MAX): 1,488,626 cycles
#     Cache: 7/10
#   Exp 8 (uses layer8.txt, 60 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E50(C:+44,494), E34(C:+22,414), E60(C:+22,410), E28(C:+22,406), E57(C:+22,362)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [50, 34, 60, 28, 57, 33, 47]
#     Cache hits: 6 (experts: [50, 34, 60, 28, 57, 33])
#     Cache misses: 1 (experts: [47])
#     NPU Time: 1,415,092 | PIM Time: 1,480,546
#     Minimum Total (MAX): 1,480,546 cycles
#     Cache: 7/10
#   Exp 9 (uses layer9.txt, 60 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E39(C:+67,646), E23(C:+44,550), E40(C:+22,640), E50(C:+22,414), E49(C:+22,410)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [39, 23, 40, 50, 49, 55, 22]
#     Cache hits: 6 (experts: [39, 23, 40, 50, 49, 55])
#     Cache misses: 1 (experts: [22])
#     NPU Time: 1,415,093 | PIM Time: 1,451,227
#     Minimum Total (MAX): 1,451,227 cycles
#     Cache: 7/10
#   Exp 10 (uses layer2.txt, 59 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E37(C:+45,182), E21(C:+44,490), E41(C:+22,414), E45(C:+22,406), E53(C:+22,354)
#     Optimal: 5 experts on NPU
#     Selected experts (by benefit): [37, 21, 41, 45, 53]
#     Cache hits: 5 (experts: [37, 21, 41, 45, 53])
#     Cache misses: 0 (experts: [])
#     NPU Time: 3,564 | PIM Time: 1,412,277
#     Minimum Total (MAX): 1,412,277 cycles
#     Cache: 6/10
#   Exp 11 (uses layer3.txt, 62 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E53(C:+22,414), E36(C:+22,410), E26(C:+22,406), E17(C:+22,354), E38(C:+22,346)
#     Optimal: 6 experts on NPU
#     Selected experts (by benefit): [53, 36, 26, 17, 38, 32]
#     Cache hits: 5 (experts: [53, 36, 26, 17, 38])
#     Cache misses: 1 (experts: [32])
#     NPU Time: 1,415,348 | PIM Time: 1,501,795
#     Minimum Total (MAX): 1,501,795 cycles
#     Cache: 7/10
#   Exp 12 (uses layer4.txt, 61 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E7(C:+22,960), E53(C:+22,952), E63(C:+22,414), E1(C:+22,410), E62(C:+22,354)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [7, 53, 63, 1, 62, 33, 50]
#     Cache hits: 6 (experts: [7, 53, 63, 1, 62, 33])
#     Cache misses: 1 (experts: [50])
#     NPU Time: 1,415,092 | PIM Time: 1,414,716
#     Minimum Total (MAX): 1,415,092 cycles
#     Cache: 7/10
#
#   ============================================================================
#   7th Optimal Total (11 experiments): 16,115,195 cycles
#
# ================================================================================
# Processing: 8th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 62 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E21(C:+45,458), E53(C:+44,752), E37(C:+23,044), E36(C:+22,414), E45(C:+22,406)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [21, 53, 37, 36, 45, 41, 4]
#     Cache hits: 6 (experts: [21, 53, 37, 36, 45, 41])
#     Cache misses: 1 (experts: [4])
#     NPU Time: 1,415,092 | PIM Time: 1,557,656
#     Minimum Total (MAX): 1,557,656 cycles
#     Cache: 7/10
#   Exp 3 (uses layer3.txt, 62 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E36(C:+44,694), E26(C:+22,575), E53(C:+22,414), E38(C:+22,414), E9(C:+22,414)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [36, 26, 53, 38, 9, 17, 37]
#     Cache hits: 6 (experts: [36, 26, 53, 38, 9, 17])
#     Cache misses: 1 (experts: [37])
#     NPU Time: 1,415,094 | PIM Time: 1,528,359
#     Minimum Total (MAX): 1,528,359 cycles
#     Cache: 8/10
#   Exp 4 (uses layer4.txt, 59 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E50(C:+45,138), E62(C:+44,546), E1(C:+44,490), E63(C:+22,414), E53(C:+22,410)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [50, 62, 1, 63, 53, 7, 33, 14]
#     Cache hits: 7 (experts: [50, 62, 1, 63, 53, 7, 33])
#     Cache misses: 1 (experts: [14])
#     NPU Time: 1,415,093 | PIM Time: 1,391,755
#     Minimum Total (MAX): 1,415,093 cycles
#     Cache: 8/10
#   Exp 5 (uses layer5.txt, 61 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E25(C:+45,270), E14(C:+45,074), E48(C:+22,583), E46(C:+22,578), E4(C:+22,432)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [25, 14, 48, 46, 4, 42, 20, 11]
#     Cache hits: 7 (experts: [25, 14, 48, 46, 4, 42, 20])
#     Cache misses: 1 (experts: [11])
#     NPU Time: 1,415,092 | PIM Time: 1,433,052
#     Minimum Total (MAX): 1,433,052 cycles
#     Cache: 8/10
#   Exp 6 (uses layer6.txt, 63 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E58(C:+23,028), E63(C:+22,414), E28(C:+22,414), E47(C:+22,406), E30(C:+22,406)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [58, 63, 28, 47, 30, 24, 44, 50]
#     Cache hits: 7 (experts: [58, 63, 28, 47, 30, 24, 44])
#     Cache misses: 1 (experts: [50])
#     NPU Time: 1,415,092 | PIM Time: 1,550,224
#     Minimum Total (MAX): 1,550,224 cycles
#     Cache: 8/10
#   Exp 7 (uses layer7.txt, 62 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E58(C:+23,576), E43(C:+22,996), E28(C:+22,575), E26(C:+22,571), E52(C:+22,414)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [58, 43, 28, 26, 52, 17, 23, 0]
#     Cache hits: 7 (experts: [58, 43, 28, 26, 52, 17, 23])
#     Cache misses: 1 (experts: [0])
#     NPU Time: 1,415,508 | PIM Time: 1,488,174
#     Minimum Total (MAX): 1,488,174 cycles
#     Cache: 8/10
#   Exp 8 (uses layer8.txt, 59 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E57(C:+66,614), E50(C:+66,610), E47(C:+44,490), E34(C:+22,944), E28(C:+22,414)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [57, 50, 47, 34, 28, 33, 60]
#     Cache hits: 7 (experts: [57, 50, 47, 34, 28, 33, 60])
#     Cache misses: 0 (experts: [])
#     NPU Time: 5,883 | PIM Time: 1,389,686
#     Minimum Total (MAX): 1,389,686 cycles
#     Cache: 7/10
#   Exp 9 (uses layer9.txt, 61 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E49(C:+44,742), E40(C:+44,550), E22(C:+23,164), E55(C:+22,884), E23(C:+22,418)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [49, 40, 22, 55, 23, 39, 52]
#     Cache hits: 6 (experts: [49, 40, 22, 55, 23, 39])
#     Cache misses: 1 (experts: [52])
#     NPU Time: 1,415,092 | PIM Time: 1,500,958
#     Minimum Total (MAX): 1,500,958 cycles
#     Cache: 8/10
#   Exp 10 (uses layer2.txt, 62 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E21(C:+45,458), E53(C:+44,752), E37(C:+23,044), E36(C:+22,414), E45(C:+22,406)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [21, 53, 37, 36, 45, 41, 4]
#     Cache hits: 6 (experts: [21, 53, 37, 36, 45, 41])
#     Cache misses: 1 (experts: [4])
#     NPU Time: 1,415,092 | PIM Time: 1,557,656
#     Minimum Total (MAX): 1,557,656 cycles
#     Cache: 7/10
#   Exp 11 (uses layer3.txt, 62 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E36(C:+44,694), E26(C:+22,575), E53(C:+22,414), E38(C:+22,414), E9(C:+22,414)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [36, 26, 53, 38, 9, 17, 37]
#     Cache hits: 6 (experts: [36, 26, 53, 38, 9, 17])
#     Cache misses: 1 (experts: [37])
#     NPU Time: 1,415,094 | PIM Time: 1,528,359
#     Minimum Total (MAX): 1,528,359 cycles
#     Cache: 8/10
#   Exp 12 (uses layer4.txt, 59 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E50(C:+45,138), E62(C:+44,546), E1(C:+44,490), E63(C:+22,414), E53(C:+22,410)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [50, 62, 1, 63, 53, 7, 33, 14]
#     Cache hits: 7 (experts: [50, 62, 1, 63, 53, 7, 33])
#     Cache misses: 1 (experts: [14])
#     NPU Time: 1,415,093 | PIM Time: 1,391,755
#     Minimum Total (MAX): 1,415,093 cycles
#     Cache: 8/10
#
#   ============================================================================
#   8th Optimal Total (11 experiments): 16,364,310 cycles
#
# ================================================================================
# Processing: 9th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 60 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E21(C:+45,406), E45(C:+45,226), E53(C:+44,490), E37(C:+22,992), E4(C:+22,984)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [21, 45, 53, 37, 4, 36, 24]
#     Cache hits: 6 (experts: [21, 45, 53, 37, 4, 36])
#     Cache misses: 1 (experts: [24])
#     NPU Time: 1,415,092 | PIM Time: 1,466,753
#     Minimum Total (MAX): 1,466,753 cycles
#     Cache: 8/10
#   Exp 3 (uses layer3.txt, 64 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E36(C:+45,266), E53(C:+23,196), E32(C:+22,928), E26(C:+22,406), E38(C:+22,406)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [36, 53, 32, 26, 38, 9, 17, 37, 58]
#     Cache hits: 8 (experts: [36, 53, 32, 26, 38, 9, 17, 37])
#     Cache misses: 1 (experts: [58])
#     NPU Time: 1,415,504 | PIM Time: 1,478,249
#     Minimum Total (MAX): 1,478,249 cycles
#     Cache: 9/10
#   Exp 4 (uses layer4.txt, 63 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E53(C:+44,744), E63(C:+44,494), E50(C:+23,052), E7(C:+22,628), E33(C:+22,414)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [53, 63, 50, 7, 33, 1, 14, 62, 59]
#     Cache hits: 8 (experts: [53, 63, 50, 7, 33, 1, 14, 62])
#     Cache misses: 1 (experts: [59])
#     NPU Time: 1,415,093 | PIM Time: 1,393,955
#     Minimum Total (MAX): 1,415,093 cycles
#     Cache: 9/10
#   Exp 5 (uses layer5.txt, 62 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E11(C:+44,490), E14(C:+44,434), E42(C:+23,036), E46(C:+22,988), E25(C:+22,788)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [11, 14, 42, 46, 25, 4, 20, 48, 34]
#     Cache hits: 8 (experts: [11, 14, 42, 46, 25, 4, 20, 48])
#     Cache misses: 1 (experts: [34])
#     NPU Time: 1,415,093 | PIM Time: 1,436,043
#     Minimum Total (MAX): 1,436,043 cycles
#     Cache: 9/10
#   Exp 6 (uses layer6.txt, 63 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E58(C:+45,258), E28(C:+44,494), E44(C:+44,494), E47(C:+44,490), E50(C:+23,073)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [58, 28, 44, 47, 50, 63, 30, 24]
#     Cache hits: 8 (experts: [58, 28, 44, 47, 50, 63, 30, 24])
#     Cache misses: 0 (experts: [])
#     NPU Time: 6,006 | PIM Time: 1,412,404
#     Minimum Total (MAX): 1,412,404 cycles
#     Cache: 8/10
#   Exp 7 (uses layer7.txt, 61 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E28(C:+44,741), E52(C:+44,494), E43(C:+44,438), E17(C:+22,414), E26(C:+22,410)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [28, 52, 43, 17, 26, 58, 0, 40]
#     Cache hits: 7 (experts: [28, 52, 43, 17, 26, 58, 0])
#     Cache misses: 1 (experts: [40])
#     NPU Time: 1,415,092 | PIM Time: 1,421,751
#     Minimum Total (MAX): 1,421,751 cycles
#     Cache: 9/10
#   Exp 8 (uses layer8.txt, 59 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E57(C:+44,796), E33(C:+44,546), E47(C:+44,490), E28(C:+44,434), E60(C:+23,300)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [57, 33, 47, 28, 60, 34, 58]
#     Cache hits: 6 (experts: [57, 33, 47, 28, 60, 34])
#     Cache misses: 1 (experts: [58])
#     NPU Time: 1,415,090 | PIM Time: 1,389,771
#     Minimum Total (MAX): 1,415,090 cycles
#     Cache: 8/10
#   Exp 9 (uses layer9.txt, 63 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E40(C:+44,494), E52(C:+44,434), E23(C:+23,428), E49(C:+22,575), E55(C:+22,406)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [40, 52, 23, 49, 55, 22, 50, 39, 35]
#     Cache hits: 8 (experts: [40, 52, 23, 49, 55, 22, 50, 39])
#     Cache misses: 1 (experts: [35])
#     NPU Time: 1,415,093 | PIM Time: 1,482,174
#     Minimum Total (MAX): 1,482,174 cycles
#     Cache: 9/10
#   Exp 10 (uses layer2.txt, 60 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E21(C:+45,406), E45(C:+45,226), E53(C:+44,490), E37(C:+22,992), E4(C:+22,984)
#     Optimal: 7 experts on NPU
#     Selected experts (by benefit): [21, 45, 53, 37, 4, 36, 24]
#     Cache hits: 6 (experts: [21, 45, 53, 37, 4, 36])
#     Cache misses: 1 (experts: [24])
#     NPU Time: 1,415,092 | PIM Time: 1,466,753
#     Minimum Total (MAX): 1,466,753 cycles
#     Cache: 8/10
#   Exp 11 (uses layer3.txt, 64 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E36(C:+45,266), E53(C:+23,196), E32(C:+22,928), E26(C:+22,406), E38(C:+22,406)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [36, 53, 32, 26, 38, 9, 17, 37, 58]
#     Cache hits: 8 (experts: [36, 53, 32, 26, 38, 9, 17, 37])
#     Cache misses: 1 (experts: [58])
#     NPU Time: 1,415,504 | PIM Time: 1,478,249
#     Minimum Total (MAX): 1,478,249 cycles
#     Cache: 9/10
#   Exp 12 (uses layer4.txt, 63 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E53(C:+44,744), E63(C:+44,494), E50(C:+23,052), E7(C:+22,628), E33(C:+22,414)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [53, 63, 50, 7, 33, 1, 14, 62, 59]
#     Cache hits: 8 (experts: [53, 63, 50, 7, 33, 1, 14, 62])
#     Cache misses: 1 (experts: [59])
#     NPU Time: 1,415,093 | PIM Time: 1,393,955
#     Minimum Total (MAX): 1,415,093 cycles
#     Cache: 9/10
#
#   ============================================================================
#   9th Optimal Total (11 experiments): 15,887,652 cycles
#
# ================================================================================
# Processing: 10th/
# ================================================================================
#
#   Exp 2 (uses layer2.txt, 58 active experts):
#     [Layer 2 has unique 64 experts, cache key = 2]
#     Top 5 by benefit: E36(C:+22,414), E24(C:+22,410), E4(C:+22,370), E53(C:+22,362), E21(C:+22,358)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [36, 24, 4, 53, 21, 37, 45, 41, 18]
#     Cache hits: 8 (experts: [36, 24, 4, 53, 21, 37, 45, 41])
#     Cache misses: 1 (experts: [18])
#     NPU Time: 1,415,500 | PIM Time: 1,406,468
#     Minimum Total (MAX): 1,415,500 cycles
#     Cache: 9/10
#   Exp 3 (uses layer3.txt, 57 active experts):
#     [Layer 3 has unique 64 experts, cache key = 3]
#     Top 5 by benefit: E36(C:+44,494), E26(C:+23,028), E37(C:+22,614), E9(C:+22,414), E17(C:+22,410)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [36, 26, 37, 9, 17, 58, 38, 53, 21]
#     Cache hits: 8 (experts: [36, 26, 37, 9, 17, 58, 38, 53])
#     Cache misses: 1 (experts: [21])
#     NPU Time: 1,415,094 | PIM Time: 1,388,464
#     Minimum Total (MAX): 1,415,094 cycles
#     Cache: 10/10
#   Exp 4 (uses layer4.txt, 61 active experts):
#     [Layer 4 has unique 64 experts, cache key = 4]
#     Top 5 by benefit: E50(C:+45,398), E7(C:+45,394), E14(C:+45,234), E33(C:+44,434), E63(C:+23,056)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [50, 7, 14, 33, 63, 53, 62, 1, 15]
#     Cache hits: 8 (experts: [50, 7, 14, 33, 63, 53, 62, 1])
#     Cache misses: 1 (experts: [15])
#     NPU Time: 1,415,094 | PIM Time: 1,397,027
#     Minimum Total (MAX): 1,415,094 cycles
#     Cache: 10/10
#   Exp 5 (uses layer5.txt, 59 active experts):
#     [Layer 5 has unique 64 experts, cache key = 5]
#     Top 5 by benefit: E20(C:+44,494), E4(C:+22,924), E34(C:+22,414), E14(C:+22,414), E48(C:+22,410)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [20, 4, 34, 14, 48, 11, 42, 46, 25]
#     Cache hits: 9 (experts: [20, 4, 34, 14, 48, 11, 42, 46, 25])
#     Cache misses: 0 (experts: [])
#     NPU Time: 5,369 | PIM Time: 1,391,350
#     Minimum Total (MAX): 1,391,350 cycles
#     Cache: 9/10
#   Exp 6 (uses layer6.txt, 61 active experts):
#     [Layer 6 has unique 64 experts, cache key = 6]
#     Top 5 by benefit: E30(C:+44,546), E50(C:+44,374), E24(C:+22,414), E28(C:+22,410), E63(C:+22,410)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [30, 50, 24, 28, 63, 47, 44, 1]
#     Cache hits: 7 (experts: [30, 50, 24, 28, 63, 47, 44])
#     Cache misses: 1 (experts: [1])
#     NPU Time: 1,415,756 | PIM Time: 1,454,904
#     Minimum Total (MAX): 1,454,904 cycles
#     Cache: 9/10
#   Exp 7 (uses layer7.txt, 58 active experts):
#     [Layer 7 has unique 64 experts, cache key = 7]
#     Top 5 by benefit: E43(C:+45,198), E23(C:+44,490), E17(C:+44,438), E40(C:+23,116), E52(C:+22,652)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [43, 23, 17, 40, 52, 28, 26, 0]
#     Cache hits: 8 (experts: [43, 23, 17, 40, 52, 28, 26, 0])
#     Cache misses: 0 (experts: [])
#     NPU Time: 5,608 | PIM Time: 1,411,414
#     Minimum Total (MAX): 1,411,414 cycles
#     Cache: 9/10
#   Exp 8 (uses layer8.txt, 57 active experts):
#     [Layer 8 has unique 64 experts, cache key = 8]
#     Top 5 by benefit: E50(C:+88,806), E34(C:+23,276), E47(C:+22,924), E57(C:+22,579), E28(C:+22,414)
#     Optimal: 8 experts on NPU
#     Selected experts (by benefit): [50, 34, 47, 57, 28, 33, 58, 60]
#     Cache hits: 8 (experts: [50, 34, 47, 57, 28, 33, 58, 60])
#     Cache misses: 0 (experts: [])
#     NPU Time: 5,628 | PIM Time: 1,390,891
#     Minimum Total (MAX): 1,390,891 cycles
#     Cache: 8/10
#   Exp 9 (uses layer9.txt, 60 active experts):
#     [Layer 9 has unique 64 experts, cache key = 9]
#     Top 5 by benefit: E39(C:+66,614), E35(C:+22,594), E52(C:+22,590), E50(C:+22,494), E40(C:+22,418)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [39, 35, 52, 50, 40, 23, 55, 49, 29]
#     Cache hits: 8 (experts: [39, 35, 52, 50, 40, 23, 55, 49])
#     Cache misses: 1 (experts: [29])
#     NPU Time: 1,415,496 | PIM Time: 1,366,110
#     Minimum Total (MAX): 1,415,496 cycles
#     Cache: 10/10
#   Exp 10 (uses layer2.txt, 58 active experts):
#     [Layer 10 has unique 64 experts, cache key = 10]
#     Top 5 by benefit: E36(C:+22,414), E24(C:+22,410), E4(C:+22,370), E53(C:+22,362), E21(C:+22,358)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [36, 24, 4, 53, 21, 37, 45, 41, 18]
#     Cache hits: 8 (experts: [36, 24, 4, 53, 21, 37, 45, 41])
#     Cache misses: 1 (experts: [18])
#     NPU Time: 1,415,500 | PIM Time: 1,406,468
#     Minimum Total (MAX): 1,415,500 cycles
#     Cache: 9/10
#   Exp 11 (uses layer3.txt, 57 active experts):
#     [Layer 11 has unique 64 experts, cache key = 11]
#     Top 5 by benefit: E36(C:+44,494), E26(C:+23,028), E37(C:+22,614), E9(C:+22,414), E17(C:+22,410)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [36, 26, 37, 9, 17, 58, 38, 53, 21]
#     Cache hits: 8 (experts: [36, 26, 37, 9, 17, 58, 38, 53])
#     Cache misses: 1 (experts: [21])
#     NPU Time: 1,415,094 | PIM Time: 1,388,464
#     Minimum Total (MAX): 1,415,094 cycles
#     Cache: 10/10
#   Exp 12 (uses layer4.txt, 61 active experts):
#     [Layer 12 has unique 64 experts, cache key = 12]
#     Top 5 by benefit: E50(C:+45,398), E7(C:+45,394), E14(C:+45,234), E33(C:+44,434), E63(C:+23,056)
#     Optimal: 9 experts on NPU
#     Selected experts (by benefit): [50, 7, 14, 33, 63, 53, 62, 1, 15]
#     Cache hits: 8 (experts: [50, 7, 14, 33, 63, 53, 62, 1])
#     Cache misses: 1 (experts: [15])
#     NPU Time: 1,415,094 | PIM Time: 1,397,027
#     Minimum Total (MAX): 1,415,094 cycles
#     Cache: 10/10
#
#   ============================================================================
#   10th Optimal Total (11 experiments): 15,555,431 cycles
#
# ================================================================================
# Numbered Folder Summaries
# ================================================================================
# Numbered Folder  Experiments Processed  Optimal Total
#             1st                     11       17690677
#             2nd                     11       17586976
#             3rd                     11       17229681
#             4th                     11       17321750
#             5th                     11       16539276
#             6th                     11       16210414
#             7th                     11       16115195
#             8th                     11       16364310
#             9th                     11       15887652
#            10th                     11       15555431
#
# ================================================================================
# GRAND TOTAL (All Optimal Configurations): 166,501,362 cycles
# ================================================================================
#
# ================================================================================
# Cache Statistics After All Iterations
# ================================================================================
#         Exp (Layer)  Cached Experts  Total Uses Avg Frequency
#  Exp 2 (layer2.txt)               9          49           5.4
#  Exp 3 (layer3.txt)              10          50           5.0
#  Exp 4 (layer4.txt)              10          54           5.4
#  Exp 5 (layer5.txt)               9          53           5.9
#  Exp 6 (layer6.txt)               9          51           5.7
#  Exp 7 (layer7.txt)               9          49           5.4
#  Exp 8 (layer8.txt)               8          49           6.1
#  Exp 9 (layer9.txt)              10          51           5.1
# Exp 10 (layer2.txt)               9          49           5.4
# Exp 11 (layer3.txt)              10          50           5.0
# Exp 12 (layer4.txt)              10          54           5.4
#
# ================================================================================
# Total Cache Hits: 456 | Total Cache Misses: 103
# Cache Hit Rate: 81.57%
# ================================================================================
#
# ================================================================================
# FINAL SUMMARY - REUSE AWARE OPTIMIZATION
# ================================================================================
# GRAND TOTAL (All Iterations with Cache): 166,501,362 cycles
# Total Experiments Processed: 110
# Cache Hit Rate: 81.57%
# ================================================================================
#   Numbered Folder  Experiments Processed  Optimal Total
# 0             1st                     11       17690677
# 1             2nd                     11       17586976
# 2             3rd                     11       17229681
# 3             4th                     11       17321750
# 4             5th                     11       16539276
# 5             6th                     11       16210414
# 6             7th                     11       16115195
# 7             8th                     11       16364310
# 8             9th                     11       15887652
# 9            10th                     11       15555431
